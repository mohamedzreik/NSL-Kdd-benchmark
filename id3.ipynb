# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, precision_recall_fscore_support
import time
import seaborn as sn

# %%
X_test = pd.read_csv('Dataset/X_test.csv')
y_test = pd.read_csv('Dataset/y_test.csv').iloc[:, 0]

X_train_30 = pd.read_csv('Dataset/X_train_30.csv')
y_train_30 = pd.read_csv('Dataset/y_train_30.csv').iloc[:, 0]

X_train_60 = pd.read_csv('Dataset/X_train_60.csv')
y_train_60 = pd.read_csv('Dataset/y_train_60.csv').iloc[:, 0]

X_train_100 = pd.read_csv('Dataset/X_train_100.csv')
y_train_100 = pd.read_csv('Dataset/y_train_100.csv').iloc[:, 0]

# %% [markdown]
# ### Train on 30%

# %%
start_time = time.time()

# %%
id3_30 = DecisionTreeClassifier(criterion='entropy', random_state=42)

# %%
id3_30.fit(X_train_30, y_train_30)
# Out:
# DecisionTreeClassifier(criterion='entropy', random_state=42)

# %%
train_time_30 = time.time() - start_time

# %%
start_time = time.time()

# %%
y_pred_30 = id3_30.predict(X_test)

# %%
test_time_30 = time.time() - start_time

# %%
accuracy_30 = accuracy_score(y_test, y_pred_30)
precision, recall, f1, _ = precision_recall_fscore_support(y_test, y_pred_30, average='weighted')

# %%
results = {}

# %%
results['30%'] = {
    'accuracy': accuracy_30,
    'precision': precision,
    'recall': recall,
    'f1': f1,
    'train_time': train_time_30,
    'test_time': test_time_30,
    'train_samples': len(X_train_30)
}

# %%
print(f"Accuracy: {accuracy_30:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1-Score: {f1:.4f}")
print(f"Training time: {train_time_30:.4f} seconds")
print(f"Testing time: {test_time_30:.4f} seconds")
print("\nClassification Report:")
print(classification_report(y_test, y_pred_30))
# Out:
# Accuracy: 0.9942
# Precision: 0.9957
# Recall: 0.9942
# F1-Score: 0.9948
# Training time: 1.3752 seconds
# Testing time: 0.1633 seconds
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     13778
#            1       0.99      0.99      0.99      3497
#            2       0.83      0.96      0.89       298
#            3       0.13      0.56      0.21        16
#            4       1.00      0.99      0.99     20203
#
#     accuracy                           0.99     37792
#    macro avg       0.79      0.90      0.82     37792
# weighted avg       1.00      0.99      0.99     37792

# %% [markdown]
# ### Train on 60%

# %%
start_time = time.time()

# %%
id3_60 = DecisionTreeClassifier(criterion='entropy', random_state=42)

# %%
id3_60.fit(X_train_60, y_train_60)
# Out:
# DecisionTreeClassifier(criterion='entropy', random_state=42)

# %%
train_time_60 = time.time() - start_time

# %%
start_time = time.time()

# %%
y_pred_60 = id3_60.predict(X_test)

# %%
test_time_60 = time.time() - start_time

# %%
accuracy_60 = accuracy_score(y_test, y_pred_60)
precision, recall, f1, _ = precision_recall_fscore_support(y_test, y_pred_60, average='weighted')

# %%
results['60%'] = {
    'accuracy': accuracy_60,
    'precision': precision,
    'recall': recall,
    'f1': f1,
    'train_time': train_time_60,
    'test_time': test_time_60,
    'train_samples': len(X_train_60)
}

# %%
print(f"Accuracy: {accuracy_60:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1-Score: {f1:.4f}")
print(f"Training time: {train_time_60:.4f} seconds")
print(f"Testing time: {test_time_60:.4f} seconds")
print("\nClassification Report:")
print(classification_report(y_test, y_pred_60))
# Out:
# Accuracy: 0.9961
# Precision: 0.9967
# Recall: 0.9961
# F1-Score: 0.9963
# Training time: 2.4238 seconds
# Testing time: 0.2950 seconds
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     13778
#            1       0.99      1.00      0.99      3497
#            2       0.90      0.96      0.93       298
#            3       0.24      0.62      0.35        16
#            4       1.00      0.99      1.00     20203
#
#     accuracy                           1.00     37792
#    macro avg       0.83      0.91      0.85     37792
# weighted avg       1.00      1.00      1.00     37792

# %% [markdown]
# ### Train on 100%

# %%
start_time = time.time()

# %%
id3_100 = DecisionTreeClassifier(criterion='entropy', random_state=42)

# %%
id3_100.fit(X_train_100, y_train_100)
# Out:
# DecisionTreeClassifier(criterion='entropy', random_state=42)

# %%
train_time_100 = time.time() - start_time

# %%
y_train_pred_100 = id3_100.predict(X_train_100)
train_accuracy_100 = accuracy_score(y_train_100, y_train_pred_100)
train_precision_100, train_recall_100, train_f1_100, _ = precision_recall_fscore_support(y_train_100, y_train_pred_100, average='weighted')

# %%
start_time = time.time()

# %%
y_pred_100 = id3_100.predict(X_test)

# %%
test_time_100 = time.time() - start_time

# %%
accuracy_100 = accuracy_score(y_test, y_pred_100)
precision, recall, f1, _ = precision_recall_fscore_support(y_test, y_pred_100, average='weighted')

# %%
results['100%'] = {
    'accuracy': accuracy_100,
    'precision': precision,
    'recall': recall,
    'f1': f1,
    'train_accuracy': train_accuracy_100,
    'train_precision': train_precision_100,
    'train_recall': train_recall_100,
    'train_f1': train_f1_100,
    'train_time': train_time_100,
    'test_time': test_time_100,
    'train_samples': len(X_train_100)
}

# %%
print("=== Training Performance ===")
print(f"Training Accuracy: {train_accuracy_100:.4f}")
print(f"Training Precision: {train_precision_100:.4f}")
print(f"Training Recall: {train_recall_100:.4f}")
print(f"Training F1-Score: {train_f1_100:.4f}")

print("\n=== Test Performance ===")
print(f"Accuracy: {accuracy_100:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1-Score: {f1:.4f}")

print(f"\nTraining time: {train_time_100:.4f} seconds")
print(f"Testing time: {test_time_100:.4f} seconds")

print("\nClassification Report:")
print(classification_report(y_test, y_pred_100))
# Out:
# === Training Performance ===
# Training Accuracy: 1.0000
# Training Precision: 1.0000
# Training Recall: 1.0000
# Training F1-Score: 1.0000
#
# === Test Performance ===
# Accuracy: 0.9968
# Precision: 0.9971
# Recall: 0.9968
# F1-Score: 0.9969
#
# Training time: 5.2177 seconds
# Testing time: 0.1895 seconds
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     13778
#            1       0.99      0.99      0.99      3497
#            2       0.94      0.95      0.94       298
#            3       0.29      0.56      0.38        16
#            4       1.00      1.00      1.00     20203
#
#     accuracy                           1.00     37792
#    macro avg       0.84      0.90      0.86     37792
# weighted avg       1.00      1.00      1.00     37792

# %%
# Create comparison DataFrame
comparison_df = pd.DataFrame(results).T
print("ID3 Decision Tree Performance Comparison:")
print("=" * 50)
print(comparison_df.round(4))
# Out:
# ID3 Decision Tree Performance Comparison:
# ==================================================
#       accuracy  precision  recall      f1  train_time  test_time  \
# 30%     0.9942     0.9957  0.9942  0.9948      1.3752     0.1633
# 60%     0.9961     0.9967  0.9961  0.9963      2.4238     0.2950
# 100%    0.9968     0.9971  0.9968  0.9969      5.2177     0.1895
#
#       train_samples  train_accuracy  train_precision  train_recall  train_f1
# 30%         70710.0             NaN              NaN           NaN       NaN
# 60%        141420.0             NaN              NaN           NaN       NaN
# 100%       235700.0             1.0              1.0           1.0       1.0

# %%
id3_30 = confusion_matrix(y_test, y_pred_30)
id3_60 = confusion_matrix(y_test, y_pred_60)
id3_100 = confusion_matrix(y_test, y_pred_100)
fig, axes = plt.subplots(1, 3, figsize=(15, 4))

# 30% training data
sn.heatmap(id3_30, annot=True, fmt='d', cmap='Blues', ax=axes[0])
axes[0].set_title('id3 - 30% Training Data')
axes[0].set_xlabel('Predicted')
axes[0].set_ylabel('Actual')

# 60% training data
sn.heatmap(id3_60, annot=True, fmt='d', cmap='Blues', ax=axes[1])
axes[1].set_title('id3 - 60% Training Data')
axes[1].set_xlabel('Predicted')
axes[1].set_ylabel('Actual')

# 100% training data
sn.heatmap(id3_100, annot=True, fmt='d', cmap='Blues', ax=axes[2])
axes[2].set_title('id3 - 100% Training Data')
axes[2].set_xlabel('Predicted')
axes[2].set_ylabel('Actual')

plt.tight_layout()
plt.show()

# Print confusion matrices
print("Confusion Matrix - 30% Training Data:")
print(id3_30)
print("\nConfusion Matrix - 60% Training Data:")
print(id3_60)
print("\nConfusion Matrix - 100% Training Data:")
print(id3_100)
# Out:
# Confusion Matrix - 30% Training Data:
# [[13774     2     0     0     2]
#  [    3  3477     0     0    17]
#  [    0     0   286     3     9]
#  [    0     0     1     9     6]
#  [   16    45    57    59 20026]]
#
# Confusion Matrix - 60% Training Data:
# [[13770     1     1     0     6]
#  [    1  3481     0     0    15]
#  [    0     1   285     0    12]
#  [    0     0     1    10     5]
#  [    9    34    30    31 20099]]
#
# Confusion Matrix - 100% Training Data:
# [[13767     2     0     0     9]
#  [    1  3479     0     0    17]
#  [    0     0   282     0    16]
#  [    0     0     1     9     6]
#  [    9    21    17    22 20134]]

# %%
from sklearn.metrics import roc_auc_score, roc_curve
import matplotlib.pyplot as plt
import numpy as np

# First, we need to recreate the models since the variable names were overwritten by confusion matrices
# Recreate the Decision Tree (ID3) models
id3_30 = DecisionTreeClassifier(criterion='entropy', random_state=42)
id3_30.fit(X_train_30, y_train_30)

id3_60 = DecisionTreeClassifier(criterion='entropy', random_state=42)
id3_60.fit(X_train_60, y_train_60)

id3_100 = DecisionTreeClassifier(criterion='entropy', random_state=42)
id3_100.fit(X_train_100, y_train_100)

# Get prediction probabilities for all models (Decision Tree has predict_proba)
y_pred_proba_30 = id3_30.predict_proba(X_test)
y_pred_proba_60 = id3_60.predict_proba(X_test)
y_pred_proba_100 = id3_100.predict_proba(X_test)

# Check number of classes
n_classes = len(np.unique(y_test))
print(f"Number of classes: {n_classes}")
print(f"Classes: {np.unique(y_test)}")

# Calculate ROC AUC for multiclass classification
roc_auc_30 = roc_auc_score(y_test, y_pred_proba_30, multi_class='ovr', average='macro')
roc_auc_60 = roc_auc_score(y_test, y_pred_proba_60, multi_class='ovr', average='macro')
roc_auc_100 = roc_auc_score(y_test, y_pred_proba_100, multi_class='ovr', average='macro')

print("\n=== ROC AUC Scores (Macro Average) ===")
print(f"ROC AUC for 30% training data:  {roc_auc_30:.4f}")
print(f"ROC AUC for 60% training data:  {roc_auc_60:.4f}")
print(f"ROC AUC for 100% training data: {roc_auc_100:.4f}")

# Also calculate weighted average ROC AUC
roc_auc_30_weighted = roc_auc_score(y_test, y_pred_proba_30, multi_class='ovr', average='weighted')
roc_auc_60_weighted = roc_auc_score(y_test, y_pred_proba_60, multi_class='ovr', average='weighted')
roc_auc_100_weighted = roc_auc_score(y_test, y_pred_proba_100, multi_class='ovr', average='weighted')

print("\n=== ROC AUC Scores (Weighted Average) ===")
print(f"ROC AUC for 30% training data:  {roc_auc_30_weighted:.4f}")
print(f"ROC AUC for 60% training data:  {roc_auc_60_weighted:.4f}")
print(f"ROC AUC for 100% training data: {roc_auc_100_weighted:.4f}")

# Fix the results dictionary structure for consistency
# Assuming you have id3_results dictionary similar to other models
id3_results['30%']['roc_auc_macro'] = roc_auc_30
id3_results['30%']['roc_auc_weighted'] = roc_auc_30_weighted

id3_results['60%']['roc_auc_macro'] = roc_auc_60
id3_results['60%']['roc_auc_weighted'] = roc_auc_60_weighted

# Fix the 100% results structure if needed (adjust based on your actual structure)
if 'test_accuracy' in id3_results['100%']:
    id3_results['100%']['accuracy'] = id3_results['100%']['test_accuracy']
    id3_results['100%']['precision'] = id3_results['100%']['test_precision']
    id3_results['100%']['recall'] = id3_results['100%']['test_recall']
    id3_results['100%']['f1'] = id3_results['100%']['test_f1']

id3_results['100%']['roc_auc_macro'] = roc_auc_100
id3_results['100%']['roc_auc_weighted'] = roc_auc_100_weighted

# Now create the comprehensive visualization
sizes = ['30%', '60%', '100%']
accuracies = [id3_results[size]['accuracy'] for size in sizes]
f1_scores = [id3_results[size]['f1'] for size in sizes]
train_times = [id3_results[size]['train_time'] for size in sizes]
roc_macro = [id3_results[size]['roc_auc_macro'] for size in sizes]
roc_weighted = [id3_results[size]['roc_auc_weighted'] for size in sizes]

fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, figsize=(15, 10))

# 1. Performance metrics comparison
x_pos = np.arange(len(sizes))
width = 0.35

ax1.bar(x_pos - width/2, accuracies, width, label='Accuracy', alpha=0.8, color='skyblue')
ax1.bar(x_pos + width/2, f1_scores, width, label='F1-Score', alpha=0.8, color='lightcoral')
ax1.set_title('Decision Tree (ID3): Accuracy vs F1-Score', fontsize=14, fontweight='bold')
ax1.set_ylabel('Score')
ax1.set_xticks(x_pos)
ax1.set_xticklabels(sizes)
ax1.legend()
ax1.grid(True, alpha=0.3)
# Adjust y-limits based on your actual performance range
y_min = min(min(accuracies), min(f1_scores)) - 0.01
y_max = max(max(accuracies), max(f1_scores)) + 0.01
ax1.set_ylim(y_min, y_max)

# Add value labels on bars
for i, (acc, f1) in enumerate(zip(accuracies, f1_scores)):
    ax1.text(i - width/2, acc + 0.0001, f'{acc:.4f}', ha='center', fontweight='bold')
    ax1.text(i + width/2, f1 + 0.0001, f'{f1:.4f}', ha='center', fontweight='bold')

# 2. ROC AUC comparison
ax2.bar(x_pos - width/2, roc_macro, width, label='ROC AUC (Macro)', alpha=0.8, color='lightgreen')
ax2.bar(x_pos + width/2, roc_weighted, width, label='ROC AUC (Weighted)', alpha=0.8, color='gold')
ax2.set_title('Decision Tree (ID3): ROC AUC Scores', fontsize=14, fontweight='bold')
ax2.set_ylabel('ROC AUC Score')
ax2.set_xticks(x_pos)
ax2.set_xticklabels(sizes)
ax2.legend()
ax2.grid(True, alpha=0.3)
# Adjust y-limits based on ROC AUC range
roc_min = min(min(roc_macro), min(roc_weighted)) - 0.005
roc_max = max(max(roc_macro), max(roc_weighted)) + 0.005
ax2.set_ylim(roc_min, roc_max)

# Add value labels
for i, (macro, weighted) in enumerate(zip(roc_macro, roc_weighted)):
    ax2.text(i - width/2, macro + 0.0001, f'{macro:.4f}', ha='center', fontweight='bold')
    ax2.text(i + width/2, weighted + 0.0001, f'{weighted:.4f}', ha='center', fontweight='bold')

# 3. Training time
bars = ax3.bar(sizes, train_times, color='purple', alpha=0.7)
ax3.set_title('Decision Tree (ID3): Training Time', fontsize=14, fontweight='bold')
ax3.set_ylabel('Time (seconds)')
ax3.grid(True, alpha=0.3)

for i, v in enumerate(train_times):
    ax3.text(i, v + max(train_times)*0.01, f'{v:.1f}s', ha='center', fontweight='bold')

# 4. Performance improvement trend
improvements_acc = [(acc - accuracies[0])*100 for acc in accuracies]
improvements_f1 = [(f1 - f1_scores[0])*100 for f1 in f1_scores]

ax4.plot(sizes, improvements_acc, 'o-', linewidth=3, markersize=8, label='Accuracy Improvement', color='blue')
ax4.plot(sizes, improvements_f1, 's-', linewidth=3, markersize=8, label='F1-Score Improvement', color='red')
ax4.set_title('Performance Improvement vs 30%', fontsize=14, fontweight='bold')
ax4.set_ylabel('Improvement (%)')
ax4.legend()
ax4.grid(True, alpha=0.3)
ax4.axhline(y=0, color='black', linestyle='--', alpha=0.5)

for i, (acc_imp, f1_imp) in enumerate(zip(improvements_acc, improvements_f1)):
    ax4.text(i, acc_imp + 0.001, f'+{acc_imp:.3f}%', ha='center', fontweight='bold', color='blue')
    ax4.text(i, f1_imp - 0.001, f'+{f1_imp:.3f}%', ha='center', fontweight='bold', color='red')

plt.tight_layout()
plt.show()

# Print comprehensive summary
print(f"\n=== Decision Tree (ID3) Performance Summary ===")
for size in sizes:
    print(f"\nDecision Tree (ID3) {size}:")
    print(f"  Accuracy: {id3_results[size]['accuracy']:.4f}")
    print(f"  F1-Score: {id3_results[size]['f1']:.4f}")
    print(f"  ROC AUC (Macro): {id3_results[size]['roc_auc_macro']:.4f}")
    print(f"  ROC AUC (Weighted): {id3_results[size]['roc_auc_weighted']:.4f}")
    print(f"  Training Time: {id3_results[size]['train_time']:.3f}s")
    print(f"  Training Samples: {id3_results[size]['train_samples']:,}")

# Key insights
print(f"\n=== Key Insights ===")
print(f"• Best Accuracy: {max(accuracies):.4f} with {sizes[np.argmax(accuracies)]} training data")
print(f"• Best F1-Score: {max(f1_scores):.4f} with {sizes[np.argmax(f1_scores)]} training data")
print(f"• Best ROC AUC (Macro): {max(roc_macro):.4f} with {sizes[np.argmax(roc_macro)]} training data")
print(f"• Training time scales roughly linearly with data size")
print(f"• Performance improvement from 30% to 100%:")
print(f"  - Accuracy: +{(accuracies[-1] - accuracies[0])*100:.3f}%")
print(f"  - F1-Score: +{(f1_scores[-1] - f1_scores[0])*100:.3f}%")
print(f"  - ROC AUC: +{(roc_macro[-1] - roc_macro[0])*100:.3f}%")

# Performance per training sample efficiency
print(f"\n=== Efficiency Analysis ===")
for i, size in enumerate(sizes):
    samples = id3_results[size]['train_samples']
    acc_per_1k = accuracies[i] / (samples / 1000)
    time_per_1k = train_times[i] / (samples / 1000)
    print(f"{size}: {acc_per_1k:.6f} accuracy per 1K samples, {time_per_1k:.3f}s per 1K samples")

# Additional Decision Tree (ID3) specific insights
print(f"\n=== Decision Tree (ID3) Specific Insights ===")
print(f"• Splitting criterion: {id3_100.criterion} (Information Gain)")
print(f"• Maximum depth: {id3_100.max_depth if id3_100.max_depth else 'Unlimited'}")
print(f"• Minimum samples split: {id3_100.min_samples_split}")
print(f"• Minimum samples leaf: {id3_100.min_samples_leaf}")
print(f"• Minimum weight fraction leaf: {id3_100.min_weight_fraction_leaf}")
print(f"• Maximum features: {id3_100.max_features if id3_100.max_features else 'All features'}")
print(f"• Maximum leaf nodes: {id3_100.max_leaf_nodes if id3_100.max_leaf_nodes else 'Unlimited'}")
print(f"• Minimum impurity decrease: {id3_100.min_impurity_decrease}")
print(f"• Class weight: {id3_100.class_weight}")
print(f"• Presort: Deprecated (automatic optimization)")

# Tree structure analysis
print(f"\n=== Tree Structure Analysis ===")
print(f"• Tree depth: {id3_100.tree_.max_depth}")
print(f"• Number of nodes: {id3_100.tree_.node_count}")
print(f"• Number of leaves: {id3_100.get_n_leaves()}")
print(f"• Number of features used: {id3_100.n_features_in_}")
print(f"• Features used in tree: {np.sum(id3_100.tree_.feature >= 0)}")

# Feature importance analysis
if hasattr(id3_100, 'feature_importances_'):
    print(f"\n=== Feature Importance Analysis ===")
    feature_importance = id3_100.feature_importances_
    if len(feature_importance) > 0:
        top_features = np.argsort(feature_importance)[-10:][::-1]  # Top 10 features
        print("Top 10 most important features:")
        for i, feat_idx in enumerate(top_features):
            if feature_importance[feat_idx] > 0:
                print(f"  {i+1}. Feature {feat_idx}: {feature_importance[feat_idx]:.4f}")
        print(f"• Total features available: {len(feature_importance)}")
        print(f"• Features actually used: {np.sum(feature_importance > 0)}")
        print(f"• Features with zero importance: {np.sum(feature_importance == 0)}")
        print(f"• Feature importance sum: {np.sum(feature_importance):.4f}")
    else:
        print("Feature importance not available")

# Decision Tree advantages and characteristics
print(f"\n=== Decision Tree (ID3) Characteristics ===")
print(f"• Algorithm: ID3 with Information Gain (Entropy)")
print(f"• Interpretability: Excellent (white-box model)")
print(f"• Feature scaling required: No")
print(f"• Handles categorical features: Yes")
print(f"• Handles missing values: No (requires preprocessing)")
print(f"• Overfitting tendency: High (especially with deep trees)")
print(f"• Training complexity: O(n*log(n)*d) where n=samples, d=features")
print(f"• Prediction complexity: O(log(n)) average case")
print(f"• Memory efficient: Yes")
print(f"• Supports incremental learning: No")
print(f"• Parallel training: No (single tree)")

# Overfitting analysis
print(f"\n=== Overfitting Analysis ===")
if id3_100.max_depth is None:
    print("⚠️  Warning: Unlimited tree depth may lead to overfitting")
if id3_100.min_samples_split == 2:
    print("⚠️  Warning: Very small min_samples_split may lead to overfitting")
if id3_100.min_samples_leaf == 1:
    print("⚠️  Warning: Very small min_samples_leaf may lead to overfitting")

print(f"• Tree depth vs dataset size ratio: {id3_100.tree_.max_depth / len(y_train_100):.6f}")
print(f"• Leaves vs samples ratio: {id3_100.get_n_leaves() / len(y_train_100):.6f}")
if id3_100.get_n_leaves() / len(y_train_100) > 0.1:
    print("⚠️  Warning: High leaves-to-samples ratio suggests potential overfitting")
# Out:
# Number of classes: 5
# Classes: [0 1 2 3 4]
#
# === ROC AUC Scores (Macro Average) ===
# ROC AUC for 30% training data:  0.9500
# ROC AUC for 60% training data:  0.9566
# ROC AUC for 100% training data: 0.9495
#
# === ROC AUC Scores (Weighted Average) ===
# ROC AUC for 30% training data:  0.9964
# ROC AUC for 60% training data:  0.9974
# ROC AUC for 100% training data: 0.9976
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[39], line 48
#      44 print(f"ROC AUC for 100% training data: {roc_auc_100_weighted:.4f}")
#      46 # Fix the results dictionary structure for consistency
#      47 # Assuming you have id3_results dictionary similar to other models
# ---> 48 id3_results['30%']['roc_auc_macro'] = roc_auc_30
#      49 id3_results['30%']['roc_auc_weighted'] = roc_auc_30_weighted
#      51 id3_results['60%']['roc_auc_macro'] = roc_auc_60
#
# NameError: name 'id3_results' is not defined
