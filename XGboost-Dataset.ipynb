# %%
import pandas as pd
import numpy as np
from xgboost import XGBClassifier
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, precision_recall_fscore_support
import time
import matplotlib.pyplot as plt
import seaborn as sn

# %%
X_test = pd.read_csv('Dataset/X_test.csv')
y_test = pd.read_csv('Dataset/y_test.csv').iloc[:, 0]

X_train_30 = pd.read_csv('Dataset/X_train_30.csv')
y_train_30 = pd.read_csv('Dataset/y_train_30.csv').iloc[:, 0]

X_train_60 = pd.read_csv('Dataset/X_train_60.csv')
y_train_60 = pd.read_csv('Dataset/y_train_60.csv').iloc[:, 0]

# %%
X_train_100 = pd.read_csv('Dataset/X_train_100.csv')
y_train_100 = pd.read_csv('Dataset/y_train_100.csv').iloc[:, 0]

# %%
xgb_results = {}

# %% [markdown]
# ### Train on 30%

# %%
start_time = time.time()

# %%
xgb_30 = XGBClassifier(random_state=42, eval_metric='logloss')

# %%
xgb_30.fit(X_train_30, y_train_30)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='logloss',
#               feature_types=None, feature_weights=None, gamma=None,
#               grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, ...)

# %%
train_time_30 = time.time() - start_time

# %%
start_time = time.time()

# %%
y_pred_30 = xgb_30.predict(X_test)

# %%
test_time_30 = time.time() - start_time

# %%
accuracy_30 = accuracy_score(y_test, y_pred_30)
precision, recall, f1, _ = precision_recall_fscore_support(y_test, y_pred_30, average='weighted')

# %%
xgb_results['30%'] = {
    'accuracy': accuracy_30,
    'precision': precision,
    'recall': recall,
    'f1': f1,
    'train_time': train_time_30,
    'test_time': test_time_30,
    'train_samples': len(X_train_30)
}

# %%
print(f"Accuracy: {accuracy_30:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1-Score: {f1:.4f}")
print(f"Training time: {train_time_30:.4f} seconds")
print(f"Testing time: {test_time_30:.4f} seconds")
print(f"Number of estimators: {xgb_30.n_estimators}")
print(f"Max depth: {xgb_30.max_depth}")
print("\nClassification Report:")
print(classification_report(y_test, y_pred_30))
# Out:
# Accuracy: 0.9973
# Precision: 0.9981
# Recall: 0.9973
# F1-Score: 0.9977
# Training time: 2.4515 seconds
# Testing time: 0.8737 seconds
# Number of estimators: None
# Max depth: None
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     13778
#            1       1.00      1.00      1.00      3497
#            2       0.93      0.98      0.95       298
#            3       0.24      0.81      0.37        16
#            4       1.00      1.00      1.00     20203
#
#     accuracy                           1.00     37792
#    macro avg       0.83      0.96      0.86     37792
# weighted avg       1.00      1.00      1.00     37792

# %% [markdown]
# ### Train on 60%

# %%
start_time = time.time()

# %%
xgb_60 = XGBClassifier(random_state=42, eval_metric='logloss')

# %%
xgb_60.fit(X_train_60, y_train_60)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='logloss',
#               feature_types=None, feature_weights=None, gamma=None,
#               grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, ...)

# %%
train_time_60 = time.time() - start_time

# %%
start_time = time.time()

# %%
y_pred_60 = xgb_60.predict(X_test)

# %%
test_time_60 = time.time() - start_time

# %%
accuracy_60 = accuracy_score(y_test, y_pred_60)
precision, recall, f1, _ = precision_recall_fscore_support(y_test, y_pred_60, average='weighted')

# %%
xgb_results['60%'] = {
    'accuracy': accuracy_60,
    'precision': precision,
    'recall': recall,
    'f1': f1,
    'train_time': train_time_60,
    'test_time': test_time_60,
    'train_samples': len(X_train_60)
}

# %%
print(f"Accuracy: {accuracy_60:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1-Score: {f1:.4f}")
print(f"Training time: {train_time_60:.4f} seconds")
print(f"Testing time: {test_time_60:.4f} seconds")
print(f"Number of estimators: {xgb_60.n_estimators}")
print(f"Max depth: {xgb_60.max_depth}")
print("\nClassification Report:")
print(classification_report(y_test, y_pred_60))
# Out:
# Accuracy: 0.9980
# Precision: 0.9984
# Recall: 0.9980
# F1-Score: 0.9982
# Training time: 20.4668 seconds
# Testing time: 0.3600 seconds
# Number of estimators: None
# Max depth: None
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     13778
#            1       1.00      1.00      1.00      3497
#            2       0.95      0.97      0.96       298
#            3       0.32      0.75      0.44        16
#            4       1.00      1.00      1.00     20203
#
#     accuracy                           1.00     37792
#    macro avg       0.85      0.94      0.88     37792
# weighted avg       1.00      1.00      1.00     37792

# %% [markdown]
# ### Train on 100%

# %%
start_time = time.time()

# %%
xgb_100 = XGBClassifier(random_state=42, eval_metric='logloss')

# %%
xgb_100.fit(X_train_100, y_train_100)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='logloss',
#               feature_types=None, feature_weights=None, gamma=None,
#               grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, ...)

# %%
train_time_100 = time.time() - start_time

# %%
y_train_pred_100 = xgb_100.predict(X_train_100)
train_accuracy_100 = accuracy_score(y_train_100, y_train_pred_100)
train_precision_100, train_recall_100, train_f1_100, _ = precision_recall_fscore_support(y_train_100, y_train_pred_100, average='weighted')

# %%
start_time = time.time()

# %%
y_pred_100 = xgb_100.predict(X_test)

# %%
test_time_100 = time.time() - start_time

# %%
accuracy_100 = accuracy_score(y_test, y_pred_100)
precision, recall, f1, _ = precision_recall_fscore_support(y_test, y_pred_100, average='weighted')

# %%
xgb_results['100%'] = {
    'train_accuracy': train_accuracy_100,
    'train_precision': train_precision_100,
    'train_recall': train_recall_100,
    'train_f1': train_f1_100,
    'test_accuracy': accuracy_100,
    'test_precision': precision,
    'test_recall': recall,
    'test_f1': f1,
    'train_time': train_time_100,
    'test_time': test_time_100,
    'train_samples': len(X_train_100),
    'n_estimators': xgb_100.n_estimators,
    'max_depth': xgb_100.max_depth,
    'learning_rate': xgb_100.learning_rate
}

# %%
print(f"Training Accuracy: {train_accuracy_100:.4f}")
print(f"Test Accuracy: {accuracy_100:.4f}")
print(f"Accuracy Gap: {(train_accuracy_100 - accuracy_100)*100:.3f}%")
print(f"Training F1-Score: {train_f1_100:.4f}")
print(f"Test F1-Score: {f1:.4f}")
print(f"F1 Gap: {(train_f1_100 - f1)*100:.3f}%")
print(f"Training time: {train_time_100:.4f} seconds")
print(f"Testing time: {test_time_100:.4f} seconds")
print(f"Number of estimators: {xgb_100.n_estimators}")
print(f"Max depth: {xgb_100.max_depth}")
print(f"Learning rate: {xgb_100.learning_rate}")
print("\nTest Set Classification Report:")
print(classification_report(y_test, y_pred_100))
# Out:
# Training Accuracy: 0.9999
# Test Accuracy: 0.9985
# Accuracy Gap: 0.143%
# Training F1-Score: 0.9999
# Test F1-Score: 0.9986
# F1 Gap: 0.133%
# Training time: 21.0162 seconds
# Testing time: 0.4641 seconds
# Number of estimators: None
# Max depth: None
# Learning rate: None
#
# Test Set Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     13778
#            1       1.00      1.00      1.00      3497
#            2       0.97      0.97      0.97       298
#            3       0.39      0.81      0.53        16
#            4       1.00      1.00      1.00     20203
#
#     accuracy                           1.00     37792
#    macro avg       0.87      0.96      0.90     37792
# weighted avg       1.00      1.00      1.00     37792

# %%
xgb_30 = confusion_matrix(y_test, y_pred_30)
xgb_60 = confusion_matrix(y_test, y_pred_60)
xgb_100 = confusion_matrix(y_test, y_pred_100)
fig, axes = plt.subplots(1, 3, figsize=(15, 4))

# 30% training data
sn.heatmap(xgb_30, annot=True, fmt='d', cmap='Blues', ax=axes[0])
axes[0].set_title('XGBoost - 30% Training Data')
axes[0].set_xlabel('Predicted')
axes[0].set_ylabel('Actual')

# 60% training data
sn.heatmap(xgb_60, annot=True, fmt='d', cmap='Blues', ax=axes[1])
axes[1].set_title('XGBoost - 60% Training Data')
axes[1].set_xlabel('Predicted')
axes[1].set_ylabel('Actual')

# 100% training data
sn.heatmap(xgb_100, annot=True, fmt='d', cmap='Blues', ax=axes[2])
axes[2].set_title('XGBoost - 100% Training Data')
axes[2].set_xlabel('Predicted')
axes[2].set_ylabel('Actual')

plt.tight_layout()
plt.show()

# Print confusion matrices
print("Confusion Matrix - 30% Training Data:")
print(xgb_30)
print("\nConfusion Matrix - 60% Training Data:")
print(xgb_60)
print("\nConfusion Matrix - 100% Training Data:")
print(xgb_100)
# Out:
# Confusion Matrix - 30% Training Data:
# [[13774     2     0     0     2]
#  [    2  3487     0     0     8]
#  [    0     0   291     2     5]
#  [    0     0     2    13     1]
#  [    4    14    20    39 20126]]
#
# Confusion Matrix - 60% Training Data:
# [[13775     1     0     0     2]
#  [    0  3486     0     0    11]
#  [    0     0   290     2     6]
#  [    0     0     2    12     2]
#  [    3    10    12    24 20154]]
#
# Confusion Matrix - 100% Training Data:
# [[13776     0     0     0     2]
#  [    0  3489     0     0     8]
#  [    0     0   290     1     7]
#  [    0     0     1    13     2]
#  [    3     5     8    19 20168]]

# %%
from sklearn.metrics import roc_auc_score, roc_curve
import matplotlib.pyplot as plt
import numpy as np

# First, we need to recreate the models since the variable names were overwritten by confusion matrices
# Recreate the XGBoost models
xgb_30 = XGBClassifier(random_state=42, eval_metric='logloss')
xgb_30.fit(X_train_30, y_train_30)

xgb_60 = XGBClassifier(random_state=42, eval_metric='logloss')
xgb_60.fit(X_train_60, y_train_60)

xgb_100 = XGBClassifier(random_state=42, eval_metric='logloss')
xgb_100.fit(X_train_100, y_train_100)

# Get prediction probabilities for all models (XGBoost has predict_proba)
y_pred_proba_30 = xgb_30.predict_proba(X_test)
y_pred_proba_60 = xgb_60.predict_proba(X_test)
y_pred_proba_100 = xgb_100.predict_proba(X_test)

# Check number of classes
n_classes = len(np.unique(y_test))
print(f"Number of classes: {n_classes}")
print(f"Classes: {np.unique(y_test)}")

# Calculate ROC AUC for multiclass classification
roc_auc_30 = roc_auc_score(y_test, y_pred_proba_30, multi_class='ovr', average='macro')
roc_auc_60 = roc_auc_score(y_test, y_pred_proba_60, multi_class='ovr', average='macro')
roc_auc_100 = roc_auc_score(y_test, y_pred_proba_100, multi_class='ovr', average='macro')

print("\n=== ROC AUC Scores (Macro Average) ===")
print(f"ROC AUC for 30% training data:  {roc_auc_30:.4f}")
print(f"ROC AUC for 60% training data:  {roc_auc_60:.4f}")
print(f"ROC AUC for 100% training data: {roc_auc_100:.4f}")

# Also calculate weighted average ROC AUC
roc_auc_30_weighted = roc_auc_score(y_test, y_pred_proba_30, multi_class='ovr', average='weighted')
roc_auc_60_weighted = roc_auc_score(y_test, y_pred_proba_60, multi_class='ovr', average='weighted')
roc_auc_100_weighted = roc_auc_score(y_test, y_pred_proba_100, multi_class='ovr', average='weighted')

print("\n=== ROC AUC Scores (Weighted Average) ===")
print(f"ROC AUC for 30% training data:  {roc_auc_30_weighted:.4f}")
print(f"ROC AUC for 60% training data:  {roc_auc_60_weighted:.4f}")
print(f"ROC AUC for 100% training data: {roc_auc_100_weighted:.4f}")

# Fix the results dictionary structure for consistency
# Assuming you have xgb_results dictionary similar to other models
xgb_results['30%']['roc_auc_macro'] = roc_auc_30
xgb_results['30%']['roc_auc_weighted'] = roc_auc_30_weighted

xgb_results['60%']['roc_auc_macro'] = roc_auc_60
xgb_results['60%']['roc_auc_weighted'] = roc_auc_60_weighted

# Fix the 100% results structure if needed (adjust based on your actual structure)
if 'test_accuracy' in xgb_results['100%']:
    xgb_results['100%']['accuracy'] = xgb_results['100%']['test_accuracy']
    xgb_results['100%']['precision'] = xgb_results['100%']['test_precision']
    xgb_results['100%']['recall'] = xgb_results['100%']['test_recall']
    xgb_results['100%']['f1'] = xgb_results['100%']['test_f1']

xgb_results['100%']['roc_auc_macro'] = roc_auc_100
xgb_results['100%']['roc_auc_weighted'] = roc_auc_100_weighted

# Now create the comprehensive visualization
sizes = ['30%', '60%', '100%']
accuracies = [xgb_results[size]['accuracy'] for size in sizes]
f1_scores = [xgb_results[size]['f1'] for size in sizes]
train_times = [xgb_results[size]['train_time'] for size in sizes]
roc_macro = [xgb_results[size]['roc_auc_macro'] for size in sizes]
roc_weighted = [xgb_results[size]['roc_auc_weighted'] for size in sizes]

fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, figsize=(15, 10))

# 1. Performance metrics comparison
x_pos = np.arange(len(sizes))
width = 0.35

ax1.bar(x_pos - width/2, accuracies, width, label='Accuracy', alpha=0.8, color='skyblue')
ax1.bar(x_pos + width/2, f1_scores, width, label='F1-Score', alpha=0.8, color='lightcoral')
ax1.set_title('XGBoost: Accuracy vs F1-Score', fontsize=14, fontweight='bold')
ax1.set_ylabel('Score')
ax1.set_xticks(x_pos)
ax1.set_xticklabels(sizes)
ax1.legend()
ax1.grid(True, alpha=0.3)
# Adjust y-limits based on your actual performance range
y_min = min(min(accuracies), min(f1_scores)) - 0.01
y_max = max(max(accuracies), max(f1_scores)) + 0.01
ax1.set_ylim(y_min, y_max)

# Add value labels on bars
for i, (acc, f1) in enumerate(zip(accuracies, f1_scores)):
    ax1.text(i - width/2, acc + 0.0001, f'{acc:.4f}', ha='center', fontweight='bold')
    ax1.text(i + width/2, f1 + 0.0001, f'{f1:.4f}', ha='center', fontweight='bold')

# 2. ROC AUC comparison
ax2.bar(x_pos - width/2, roc_macro, width, label='ROC AUC (Macro)', alpha=0.8, color='lightgreen')
ax2.bar(x_pos + width/2, roc_weighted, width, label='ROC AUC (Weighted)', alpha=0.8, color='gold')
ax2.set_title('XGBoost: ROC AUC Scores', fontsize=14, fontweight='bold')
ax2.set_ylabel('ROC AUC Score')
ax2.set_xticks(x_pos)
ax2.set_xticklabels(sizes)
ax2.legend()
ax2.grid(True, alpha=0.3)
# Adjust y-limits based on ROC AUC range
roc_min = min(min(roc_macro), min(roc_weighted)) - 0.005
roc_max = max(max(roc_macro), max(roc_weighted)) + 0.005
ax2.set_ylim(roc_min, roc_max)

# Add value labels
for i, (macro, weighted) in enumerate(zip(roc_macro, roc_weighted)):
    ax2.text(i - width/2, macro + 0.0001, f'{macro:.4f}', ha='center', fontweight='bold')
    ax2.text(i + width/2, weighted + 0.0001, f'{weighted:.4f}', ha='center', fontweight='bold')

# 3. Training time
bars = ax3.bar(sizes, train_times, color='purple', alpha=0.7)
ax3.set_title('XGBoost: Training Time', fontsize=14, fontweight='bold')
ax3.set_ylabel('Time (seconds)')
ax3.grid(True, alpha=0.3)

for i, v in enumerate(train_times):
    ax3.text(i, v + max(train_times)*0.01, f'{v:.1f}s', ha='center', fontweight='bold')

# 4. Performance improvement trend
improvements_acc = [(acc - accuracies[0])*100 for acc in accuracies]
improvements_f1 = [(f1 - f1_scores[0])*100 for f1 in f1_scores]

ax4.plot(sizes, improvements_acc, 'o-', linewidth=3, markersize=8, label='Accuracy Improvement', color='blue')
ax4.plot(sizes, improvements_f1, 's-', linewidth=3, markersize=8, label='F1-Score Improvement', color='red')
ax4.set_title('Performance Improvement vs 30%', fontsize=14, fontweight='bold')
ax4.set_ylabel('Improvement (%)')
ax4.legend()
ax4.grid(True, alpha=0.3)
ax4.axhline(y=0, color='black', linestyle='--', alpha=0.5)

for i, (acc_imp, f1_imp) in enumerate(zip(improvements_acc, improvements_f1)):
    ax4.text(i, acc_imp + 0.001, f'+{acc_imp:.3f}%', ha='center', fontweight='bold', color='blue')
    ax4.text(i, f1_imp - 0.001, f'+{f1_imp:.3f}%', ha='center', fontweight='bold', color='red')

plt.tight_layout()
plt.show()

# Print comprehensive summary
print(f"\n=== XGBoost Performance Summary ===")
for size in sizes:
    print(f"\nXGBoost {size}:")
    print(f"  Accuracy: {xgb_results[size]['accuracy']:.4f}")
    print(f"  F1-Score: {xgb_results[size]['f1']:.4f}")
    print(f"  ROC AUC (Macro): {xgb_results[size]['roc_auc_macro']:.4f}")
    print(f"  ROC AUC (Weighted): {xgb_results[size]['roc_auc_weighted']:.4f}")
    print(f"  Training Time: {xgb_results[size]['train_time']:.3f}s")
    print(f"  Training Samples: {xgb_results[size]['train_samples']:,}")

# Key insights
print(f"\n=== Key Insights ===")
print(f"• Best Accuracy: {max(accuracies):.4f} with {sizes[np.argmax(accuracies)]} training data")
print(f"• Best F1-Score: {max(f1_scores):.4f} with {sizes[np.argmax(f1_scores)]} training data")
print(f"• Best ROC AUC (Macro): {max(roc_macro):.4f} with {sizes[np.argmax(roc_macro)]} training data")
print(f"• Training time scales with data size and tree complexity")
print(f"• Performance improvement from 30% to 100%:")
print(f"  - Accuracy: +{(accuracies[-1] - accuracies[0])*100:.3f}%")
print(f"  - F1-Score: +{(f1_scores[-1] - f1_scores[0])*100:.3f}%")
print(f"  - ROC AUC: +{(roc_macro[-1] - roc_macro[0])*100:.3f}%")

# Performance per training sample efficiency
print(f"\n=== Efficiency Analysis ===")
for i, size in enumerate(sizes):
    samples = xgb_results[size]['train_samples']
    acc_per_1k = accuracies[i] / (samples / 1000)
    time_per_1k = train_times[i] / (samples / 1000)
    print(f"{size}: {acc_per_1k:.6f} accuracy per 1K samples, {time_per_1k:.3f}s per 1K samples")

# Additional XGBoost specific insights
print(f"\n=== XGBoost Specific Insights ===")
print(f"• Number of estimators (trees): {xgb_100.n_estimators}")
print(f"• Learning rate: {xgb_100.learning_rate}")
print(f"• Max depth: {xgb_100.max_depth}")
print(f"• Subsample ratio: {xgb_100.subsample}")
print(f"• Column subsample by tree: {xgb_100.colsample_bytree}")
print(f"• Regularization alpha: {xgb_100.reg_alpha}")
print(f"• Regularization lambda: {xgb_100.reg_lambda}")
print(f"• Objective function: {xgb_100.objective}")
print(f"• Evaluation metric: {xgb_100.eval_metric}")
print(f"• Built-in feature importance: Yes")
print(f"• Handles missing values: Yes")
print(f"• GPU acceleration available: Yes (if configured)")
print(f"• Early stopping available: Yes (if configured)")
print(f"• Cross-validation built-in: Yes")

# Feature importance analysis (if available)
if hasattr(xgb_100, 'feature_importances_'):
    print(f"\n=== Feature Importance Analysis ===")
    feature_importance = xgb_100.feature_importances_
    top_features = np.argsort(feature_importance)[-10:][::-1]  # Top 10 features
    print("Top 10 most important features:")
    for i, feat_idx in enumerate(top_features):
        print(f"  {i+1}. Feature {feat_idx}: {feature_importance[feat_idx]:.4f}")
    print(f"• Total features used: {len(feature_importance)}")
    print(f"• Features with zero importance: {np.sum(feature_importance == 0)}")
# Out:
# Number of classes: 5
# Classes: [0 1 2 3 4]
#
# === ROC AUC Scores (Macro Average) ===
# ROC AUC for 30% training data:  0.9999
# ROC AUC for 60% training data:  0.9999
# ROC AUC for 100% training data: 0.9999
#
# === ROC AUC Scores (Weighted Average) ===
# ROC AUC for 30% training data:  1.0000
# ROC AUC for 60% training data:  1.0000
# ROC AUC for 100% training data: 1.0000
# === XGBoost Performance Summary ===
#
# XGBoost 30%:
#   Accuracy: 0.9973
#   F1-Score: 0.9977
#   ROC AUC (Macro): 0.9999
#   ROC AUC (Weighted): 1.0000
#   Training Time: 2.451s
#   Training Samples: 70,710
#
# XGBoost 60%:
#   Accuracy: 0.9980
#   F1-Score: 0.9982
#   ROC AUC (Macro): 0.9999
#   ROC AUC (Weighted): 1.0000
#   Training Time: 20.467s
#   Training Samples: 141,420
#
# XGBoost 100%:
#   Accuracy: 0.9985
#   F1-Score: 0.9986
#   ROC AUC (Macro): 0.9999
#   ROC AUC (Weighted): 1.0000
#   Training Time: 21.016s
#   Training Samples: 235,700
#
# === Key Insights ===
# • Best Accuracy: 0.9985 with 100% training data
# • Best F1-Score: 0.9986 with 100% training data
# • Best ROC AUC (Macro): 0.9999 with 100% training data
# • Training time scales with data size and tree complexity
# • Performance improvement from 30% to 100%:
#   - Accuracy: +0.119%
#   - F1-Score: +0.097%
#   - ROC AUC: +0.004%
#
# === Efficiency Analysis ===
# 30%: 0.014104 accuracy per 1K samples, 0.035s per 1K samples
# 60%: 0.007057 accuracy per 1K samples, 0.145s per 1K samples
# 100%: 0.004236 accuracy per 1K samples, 0.089s per 1K samples
#
# === XGBoost Specific Insights ===
# • Number of estimators (trees): None
# • Learning rate: None
# • Max depth: None
# • Subsample ratio: None
# • Column subsample by tree: None
# • Regularization alpha: None
# • Regularization lambda: None
# • Objective function: multi:softprob
# • Evaluation metric: logloss
# • Built-in feature importance: Yes
# • Handles missing values: Yes
# • GPU acceleration available: Yes (if configured)
# • Early stopping available: Yes (if configured)
# • Cross-validation built-in: Yes
#
# === Feature Importance Analysis ===
# Top 10 most important features:
#   1. Feature 17: 0.5313
#   2. Feature 13: 0.1327
#   3. Feature 10: 0.0579
#   4. Feature 12: 0.0450
#   5. Feature 9: 0.0325
#   6. Feature 2: 0.0309
#   7. Feature 14: 0.0252
#   8. Feature 8: 0.0216
#   9. Feature 4: 0.0204
#   10. Feature 7: 0.0165
# • Total features used: 20
# • Features with zero importance: 0
