# %%
import pandas as pd
import numpy as np
from lightgbm import LGBMClassifier
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, precision_recall_fscore_support
import time
import matplotlib.pyplot as plt
import seaborn as sn

# %%
X_test = pd.read_csv('Dataset/X_test.csv')
y_test = pd.read_csv('Dataset/y_test.csv').iloc[:, 0]

X_train_30 = pd.read_csv('Dataset/X_train_30.csv')
y_train_30 = pd.read_csv('Dataset/y_train_30.csv').iloc[:, 0]

X_train_60 = pd.read_csv('Dataset/X_train_60.csv')
y_train_60 = pd.read_csv('Dataset/y_train_60.csv').iloc[:, 0]

X_train_100 = pd.read_csv('Dataset/X_train_100.csv')
y_train_100 = pd.read_csv('Dataset/y_train_100.csv').iloc[:, 0]

# %%
lgbm_results = {}

# %%
start_time = time.time()

# %%
lgbm_30 = LGBMClassifier(random_state=42, verbose=-1)

# %%
lgbm_30.fit(X_train_30, y_train_30)
# Out:
# LGBMClassifier(random_state=42, verbose=-1)

# %%
train_time_30 = time.time() - start_time

# %%
start_time = time.time()

# %%
y_pred_30 = lgbm_30.predict(X_test)

# %%
test_time_30 = time.time() - start_time

# %%
accuracy_30 = accuracy_score(y_test, y_pred_30)
precision, recall, f1, _ = precision_recall_fscore_support(y_test, y_pred_30, average='weighted')

# %%
lgbm_results['30%'] = {
    'accuracy': accuracy_30,
    'precision': precision,
    'recall': recall,
    'f1': f1,
    'train_time': train_time_30,
    'test_time': test_time_30,
    'train_samples': len(X_train_30)
}

# %%
print(f"Accuracy: {accuracy_30:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1-Score: {f1:.4f}")
print(f"Training time: {train_time_30:.4f} seconds")
print(f"Testing time: {test_time_30:.4f} seconds")
print(f"Number of estimators: {lgbm_30.n_estimators}")
print(f"Max depth: {lgbm_30.max_depth}")
print("\nClassification Report:")
print(classification_report(y_test, y_pred_30))
# Out:
# Accuracy: 0.9977
# Precision: 0.9983
# Recall: 0.9977
# F1-Score: 0.9979
# Training time: 5.3401 seconds
# Testing time: 0.4522 seconds
# Number of estimators: 100
# Max depth: -1
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     13778
#            1       1.00      1.00      1.00      3497
#            2       0.94      0.98      0.96       298
#            3       0.27      0.81      0.40        16
#            4       1.00      1.00      1.00     20203
#
#     accuracy                           1.00     37792
#    macro avg       0.84      0.96      0.87     37792
# weighted avg       1.00      1.00      1.00     37792

# %% [markdown]
# ### Train on 60%

# %%
start_time = time.time()

# %%
lgbm_60 = LGBMClassifier(random_state=42, verbose=-1)

# %%
lgbm_60.fit(X_train_60, y_train_60)
# Out:
# LGBMClassifier(random_state=42, verbose=-1)

# %%
train_time_60 = time.time() - start_time

# %%
start_time = time.time()

# %%
y_pred_60 = lgbm_60.predict(X_test)

# %%
test_time_60 = time.time() - start_time

# %%
accuracy_60 = accuracy_score(y_test, y_pred_60)
precision, recall, f1, _ = precision_recall_fscore_support(y_test, y_pred_60, average='weighted')

# %%
accuracy_60 = accuracy_score(y_test, y_pred_60)
precision, recall, f1, _ = precision_recall_fscore_support(y_test, y_pred_60, average='weighted')

# %%
lgbm_results['60%'] = {
    'accuracy': accuracy_60,
    'precision': precision,
    'recall': recall,
    'f1': f1,
    'train_time': train_time_60,
    'test_time': test_time_60,
    'train_samples': len(X_train_60)
}

# %%
print(f"Accuracy: {accuracy_60:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1-Score: {f1:.4f}")
print(f"Training time: {train_time_60:.4f} seconds")
print(f"Testing time: {test_time_60:.4f} seconds")
print(f"Number of estimators: {lgbm_60.n_estimators}")
print(f"Max depth: {lgbm_60.max_depth}")
print("\nClassification Report:")
print(classification_report(y_test, y_pred_60))
# Out:
# Accuracy: 0.9981
# Precision: 0.9984
# Recall: 0.9981
# F1-Score: 0.9982
# Training time: 3.9171 seconds
# Testing time: 0.5246 seconds
# Number of estimators: 100
# Max depth: -1
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     13778
#            1       1.00      1.00      1.00      3497
#            2       0.96      0.97      0.97       298
#            3       0.33      0.69      0.45        16
#            4       1.00      1.00      1.00     20203
#
#     accuracy                           1.00     37792
#    macro avg       0.86      0.93      0.88     37792
# weighted avg       1.00      1.00      1.00     37792

# %% [markdown]
# ### Train on 100%

# %%
start_time = time.time()

# %%
lgbm_100 = LGBMClassifier(random_state=42, verbose=-1)

# %%
lgbm_100.fit(X_train_100, y_train_100)
# Out:
# LGBMClassifier(random_state=42, verbose=-1)

# %%
train_time_100 = time.time() - start_time

# %%
y_train_pred_100 = lgbm_100.predict(X_train_100)
train_accuracy_100 = accuracy_score(y_train_100, y_train_pred_100)
train_precision_100, train_recall_100, train_f1_100, _ = precision_recall_fscore_support(y_train_100, y_train_pred_100, average='weighted')

# %%
start_time = time.time()

# %%
y_pred_100 = lgbm_100.predict(X_test)

# %%
test_time_100 = time.time() - start_time

# %%
accuracy_100 = accuracy_score(y_test, y_pred_100)
precision, recall, f1, _ = precision_recall_fscore_support(y_test, y_pred_100, average='weighted')

# %%
lgbm_results['100%'] = {
    'train_accuracy': train_accuracy_100,
    'train_precision': train_precision_100,
    'train_recall': train_recall_100,
    'train_f1': train_f1_100,
    'test_accuracy': accuracy_100,
    'test_precision': precision,
    'test_recall': recall,
    'test_f1': f1,
    'train_time': train_time_100,
    'test_time': test_time_100,
    'train_samples': len(X_train_100)
}

# %%
print(f"Training Accuracy: {train_accuracy_100:.4f}")
print(f"Test Accuracy: {accuracy_100:.4f}")
print(f"Accuracy Gap: {(train_accuracy_100 - accuracy_100)*100:.3f}%")
print(f"Training F1-Score: {train_f1_100:.4f}")
print(f"Test F1-Score: {f1:.4f}")
print(f"F1 Gap: {(train_f1_100 - f1)*100:.3f}%")
print(f"Training time: {train_time_100:.4f} seconds")
print(f"Testing time: {test_time_100:.4f} seconds")
print(f"Number of estimators: {lgbm_100.n_estimators}")
print(f"Max depth: {lgbm_100.max_depth}")
print("\nTest Set Classification Report:")
print(classification_report(y_test, y_pred_100))
# Out:
# Training Accuracy: 1.0000
# Test Accuracy: 0.9985
# Accuracy Gap: 0.146%
# Training F1-Score: 1.0000
# Test F1-Score: 0.9986
# F1 Gap: 0.136%
# Training time: 13.1987 seconds
# Testing time: 0.5160 seconds
# Number of estimators: 100
# Max depth: -1
#
# Test Set Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     13778
#            1       1.00      1.00      1.00      3497
#            2       0.97      0.98      0.98       298
#            3       0.35      0.69      0.47        16
#            4       1.00      1.00      1.00     20203
#
#     accuracy                           1.00     37792
#    macro avg       0.87      0.93      0.89     37792
# weighted avg       1.00      1.00      1.00     37792

# %%
sizes = ['30%', '60%', '100%']
accuracies = [lgbm_results['30%']['accuracy'], lgbm_results['60%']['accuracy'], lgbm_results['100%']['accuracy']]
f1_scores = [lgbm_results['30%']['f1'], lgbm_results['60%']['f1'], lgbm_results['100%']['f1']]
train_times = [lgbm_results['30%']['train_time'], lgbm_results['60%']['train_time'], lgbm_results['100%']['train_time']]

fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, figsize=(12, 8))

# 1. Zoomed accuracy plot
ax1.plot(sizes, accuracies, 'bo-', linewidth=3, markersize=10)
ax1.set_title('LightGBM: Accuracy (Zoomed)', fontsize=12, fontweight='bold')
ax1.set_ylabel('Accuracy')
ax1.set_ylim(min(accuracies) - 0.001, max(accuracies) + 0.001)
ax1.grid(True, alpha=0.3)
for i, v in enumerate(accuracies):
    ax1.text(i, v + 0.0002, f'{v:.4f}', ha='center', fontweight='bold')

# 2. Zoomed F1-score plot
ax2.plot(sizes, f1_scores, 'ro-', linewidth=3, markersize=10)
ax2.set_title('LightGBM: F1-Score (Zoomed)', fontsize=12, fontweight='bold')
ax2.set_ylabel('F1-Score')
ax2.set_ylim(min(f1_scores) - 0.001, max(f1_scores) + 0.001)
ax2.grid(True, alpha=0.3)
for i, v in enumerate(f1_scores):
    ax2.text(i, v + 0.0002, f'{v:.4f}', ha='center', fontweight='bold')

# 3. Training time
ax3.bar(sizes, train_times, color='green', alpha=0.7)
ax3.set_title('LightGBM: Training Time', fontsize=12, fontweight='bold')
ax3.set_ylabel('Time (seconds)')
for i, v in enumerate(train_times):
    ax3.text(i, v + max(train_times)*0.01, f'{v:.1f}s', ha='center', fontweight='bold')

# 4. Performance improvement
improvements_acc = [(acc - accuracies[0])*100 for acc in accuracies]
ax4.bar(sizes, improvements_acc, color='purple', alpha=0.7)
ax4.set_title('Accuracy Improvement vs 30%', fontsize=12, fontweight='bold')
ax4.set_ylabel('Improvement (%)')
ax4.axhline(y=0, color='black', linestyle='--', alpha=0.5)
for i, v in enumerate(improvements_acc):
    ax4.text(i, v + 0.001, f'+{v:.3f}%', ha='center', fontweight='bold')

plt.tight_layout()
plt.show()

print(f"\nLightGBM Summary:")
for size in sizes:
    print(f"LightGBM {size}: Accuracy={lgbm_results[size]['accuracy']:.4f}, F1={lgbm_results[size]['f1']:.4f}, Time={lgbm_results[size]['train_time']:.3f}s")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[36], line 2
#       1 sizes = ['30%', '60%', '100%']
# ----> 2 accuracies = [lgbm_results['30%']['accuracy'], lgbm_results['60%']['accuracy'], lgbm_results['100%']['accuracy']]
#       3 f1_scores = [lgbm_results['30%']['f1'], lgbm_results['60%']['f1'], lgbm_results['100%']['f1']]
#       4 train_times = [lgbm_results['30%']['train_time'], lgbm_results['60%']['train_time'], lgbm_results['100%']['train_time']]
#
# KeyError: 'accuracy'

# %%
lgbm_30 = confusion_matrix(y_test, y_pred_30)
lgbm_60 = confusion_matrix(y_test, y_pred_60)
lgbm_100 = confusion_matrix(y_test, y_pred_100)
fig, axes = plt.subplots(1, 3, figsize=(15, 4))

# 30% training data
sn.heatmap(lgbm_30, annot=True, fmt='d', cmap='Blues', ax=axes[0])
axes[0].set_title('LightGBM - 30% Training Data')
axes[0].set_xlabel('Predicted')
axes[0].set_ylabel('Actual')

# 60% training data
sn.heatmap(lgbm_60, annot=True, fmt='d', cmap='Blues', ax=axes[1])
axes[1].set_title('LightGBM - 60% Training Data')
axes[1].set_xlabel('Predicted')
axes[1].set_ylabel('Actual')

# 100% training data
sn.heatmap(lgbm_100, annot=True, fmt='d', cmap='Blues', ax=axes[2])
axes[2].set_title('LightGBM - 100% Training Data')
axes[2].set_xlabel('Predicted')
axes[2].set_ylabel('Actual')

plt.tight_layout()
plt.show()

# Print confusion matrices
print("Confusion Matrix - 30% Training Data:")
print(lgbm_30)
print("\nConfusion Matrix - 60% Training Data:")
print(lgbm_60)
print("\nConfusion Matrix - 100% Training Data:")
print(lgbm_100)
# Out:
# Confusion Matrix - 30% Training Data:
# [[13774     0     0     0     4]
#  [    1  3489     0     0     7]
#  [    0     0   292     2     4]
#  [    0     0     3    13     0]
#  [    9    10    14    34 20136]]
#
# Confusion Matrix - 60% Training Data:
# [[13772     0     0     0     6]
#  [    1  3490     0     0     6]
#  [    0     0   290     1     7]
#  [    0     0     1    11     4]
#  [    5    10    11    21 20156]]
#
# Confusion Matrix - 100% Training Data:
# [[13771     1     0     0     6]
#  [    0  3491     0     0     6]
#  [    0     0   292     2     4]
#  [    0     0     1    11     4]
#  [    5     3     7    18 20170]]

# %%
from sklearn.metrics import roc_auc_score, roc_curve
import matplotlib.pyplot as plt
import numpy as np

# First, we need to recreate the models since the variable names were overwritten by confusion matrices
# Recreate the LightGBM models
model_30 = LGBMClassifier(random_state=42, verbose=-1)
model_30.fit(X_train_30, y_train_30)

model_60 = LGBMClassifier(random_state=42, verbose=-1)
model_60.fit(X_train_60, y_train_60)

model_100 = LGBMClassifier(random_state=42, verbose=-1)
model_100.fit(X_train_100, y_train_100)

# Get prediction probabilities for all models
y_pred_proba_30 = model_30.predict_proba(X_test)
y_pred_proba_60 = model_60.predict_proba(X_test)
y_pred_proba_100 = model_100.predict_proba(X_test)

# Check number of classes
n_classes = len(np.unique(y_test))
print(f"Number of classes: {n_classes}")
print(f"Classes: {np.unique(y_test)}")

# Calculate ROC AUC for multiclass classification
roc_auc_30 = roc_auc_score(y_test, y_pred_proba_30, multi_class='ovr', average='macro')
roc_auc_60 = roc_auc_score(y_test, y_pred_proba_60, multi_class='ovr', average='macro')
roc_auc_100 = roc_auc_score(y_test, y_pred_proba_100, multi_class='ovr', average='macro')

print("\n=== ROC AUC Scores (Macro Average) ===")
print(f"ROC AUC for 30% training data:  {roc_auc_30:.4f}")
print(f"ROC AUC for 60% training data:  {roc_auc_60:.4f}")
print(f"ROC AUC for 100% training data: {roc_auc_100:.4f}")

# Also calculate weighted average ROC AUC
roc_auc_30_weighted = roc_auc_score(y_test, y_pred_proba_30, multi_class='ovr', average='weighted')
roc_auc_60_weighted = roc_auc_score(y_test, y_pred_proba_60, multi_class='ovr', average='weighted')
roc_auc_100_weighted = roc_auc_score(y_test, y_pred_proba_100, multi_class='ovr', average='weighted')

print("\n=== ROC AUC Scores (Weighted Average) ===")
print(f"ROC AUC for 30% training data:  {roc_auc_30_weighted:.4f}")
print(f"ROC AUC for 60% training data:  {roc_auc_60_weighted:.4f}")
print(f"ROC AUC for 100% training data: {roc_auc_100_weighted:.4f}")

# Fix the results dictionary structure for consistency
# The 100% case has different key names, let's standardize them
lgbm_results['30%']['roc_auc_macro'] = roc_auc_30
lgbm_results['30%']['roc_auc_weighted'] = roc_auc_30_weighted

lgbm_results['60%']['roc_auc_macro'] = roc_auc_60
lgbm_results['60%']['roc_auc_weighted'] = roc_auc_60_weighted

# Fix the 100% results structure
lgbm_results['100%']['accuracy'] = lgbm_results['100%']['test_accuracy']  # Standardize key names
lgbm_results['100%']['precision'] = lgbm_results['100%']['test_precision']
lgbm_results['100%']['recall'] = lgbm_results['100%']['test_recall']
lgbm_results['100%']['f1'] = lgbm_results['100%']['test_f1']
lgbm_results['100%']['roc_auc_macro'] = roc_auc_100
lgbm_results['100%']['roc_auc_weighted'] = roc_auc_100_weighted

# Now create the corrected visualization
sizes = ['30%', '60%', '100%']
accuracies = [lgbm_results[size]['accuracy'] for size in sizes]
f1_scores = [lgbm_results[size]['f1'] for size in sizes]
train_times = [lgbm_results[size]['train_time'] for size in sizes]
roc_macro = [lgbm_results[size]['roc_auc_macro'] for size in sizes]
roc_weighted = [lgbm_results[size]['roc_auc_weighted'] for size in sizes]

fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, figsize=(15, 10))

# 1. Performance metrics comparison
x_pos = np.arange(len(sizes))
width = 0.35

ax1.bar(x_pos - width/2, accuracies, width, label='Accuracy', alpha=0.8, color='skyblue')
ax1.bar(x_pos + width/2, f1_scores, width, label='F1-Score', alpha=0.8, color='lightcoral')
ax1.set_title('LightGBM: Accuracy vs F1-Score', fontsize=14, fontweight='bold')
ax1.set_ylabel('Score')
ax1.set_xticks(x_pos)
ax1.set_xticklabels(sizes)
ax1.legend()
ax1.grid(True, alpha=0.3)
ax1.set_ylim(0.99, 1.0)

# Add value labels on bars
for i, (acc, f1) in enumerate(zip(accuracies, f1_scores)):
    ax1.text(i - width/2, acc + 0.0001, f'{acc:.4f}', ha='center', fontweight='bold')
    ax1.text(i + width/2, f1 + 0.0001, f'{f1:.4f}', ha='center', fontweight='bold')

# 2. ROC AUC comparison
ax2.bar(x_pos - width/2, roc_macro, width, label='ROC AUC (Macro)', alpha=0.8, color='lightgreen')
ax2.bar(x_pos + width/2, roc_weighted, width, label='ROC AUC (Weighted)', alpha=0.8, color='gold')
ax2.set_title('LightGBM: ROC AUC Scores', fontsize=14, fontweight='bold')
ax2.set_ylabel('ROC AUC Score')
ax2.set_xticks(x_pos)
ax2.set_xticklabels(sizes)
ax2.legend()
ax2.grid(True, alpha=0.3)
ax2.set_ylim(0.99, 1.0)

# Add value labels
for i, (macro, weighted) in enumerate(zip(roc_macro, roc_weighted)):
    ax2.text(i - width/2, macro + 0.0001, f'{macro:.4f}', ha='center', fontweight='bold')
    ax2.text(i + width/2, weighted + 0.0001, f'{weighted:.4f}', ha='center', fontweight='bold')

# 3. Training time
bars = ax3.bar(sizes, train_times, color='purple', alpha=0.7)
ax3.set_title('LightGBM: Training Time', fontsize=14, fontweight='bold')
ax3.set_ylabel('Time (seconds)')
ax3.grid(True, alpha=0.3)

for i, v in enumerate(train_times):
    ax3.text(i, v + max(train_times)*0.01, f'{v:.1f}s', ha='center', fontweight='bold')

# 4. Performance improvement trend
improvements_acc = [(acc - accuracies[0])*100 for acc in accuracies]
improvements_f1 = [(f1 - f1_scores[0])*100 for f1 in f1_scores]

ax4.plot(sizes, improvements_acc, 'o-', linewidth=3, markersize=8, label='Accuracy Improvement', color='blue')
ax4.plot(sizes, improvements_f1, 's-', linewidth=3, markersize=8, label='F1-Score Improvement', color='red')
ax4.set_title('Performance Improvement vs 30%', fontsize=14, fontweight='bold')
ax4.set_ylabel('Improvement (%)')
ax4.legend()
ax4.grid(True, alpha=0.3)
ax4.axhline(y=0, color='black', linestyle='--', alpha=0.5)

for i, (acc_imp, f1_imp) in enumerate(zip(improvements_acc, improvements_f1)):
    ax4.text(i, acc_imp + 0.001, f'+{acc_imp:.3f}%', ha='center', fontweight='bold', color='blue')
    ax4.text(i, f1_imp - 0.001, f'+{f1_imp:.3f}%', ha='center', fontweight='bold', color='red')

plt.tight_layout()
plt.show()

# Print comprehensive summary
print(f"\n=== LightGBM Performance Summary ===")
for size in sizes:
    print(f"\nLightGBM {size}:")
    print(f"  Accuracy: {lgbm_results[size]['accuracy']:.4f}")
    print(f"  F1-Score: {lgbm_results[size]['f1']:.4f}")
    print(f"  ROC AUC (Macro): {lgbm_results[size]['roc_auc_macro']:.4f}")
    print(f"  ROC AUC (Weighted): {lgbm_results[size]['roc_auc_weighted']:.4f}")
    print(f"  Training Time: {lgbm_results[size]['train_time']:.3f}s")
    print(f"  Training Samples: {lgbm_results[size]['train_samples']:,}")

# Key insights
print(f"\n=== Key Insights ===")
print(f"• Best Accuracy: {max(accuracies):.4f} with {sizes[np.argmax(accuracies)]} training data")
print(f"• Best F1-Score: {max(f1_scores):.4f} with {sizes[np.argmax(f1_scores)]} training data")
print(f"• Best ROC AUC (Macro): {max(roc_macro):.4f} with {sizes[np.argmax(roc_macro)]} training data")
print(f"• Training time scales roughly linearly with data size")
print(f"• Performance improvement from 30% to 100%:")
print(f"  - Accuracy: +{(accuracies[-1] - accuracies[0])*100:.3f}%")
print(f"  - F1-Score: +{(f1_scores[-1] - f1_scores[0])*100:.3f}%")
print(f"  - ROC AUC: +{(roc_macro[-1] - roc_macro[0])*100:.3f}%")

# Performance per training sample efficiency
print(f"\n=== Efficiency Analysis ===")
for i, size in enumerate(sizes):
    samples = lgbm_results[size]['train_samples']
    acc_per_1k = accuracies[i] / (samples / 1000)
    time_per_1k = train_times[i] / (samples / 1000)
    print(f"{size}: {acc_per_1k:.6f} accuracy per 1K samples, {time_per_1k:.3f}s per 1K samples")
# Out:
# Number of classes: 5
# Classes: [0 1 2 3 4]
#
# === ROC AUC Scores (Macro Average) ===
# ROC AUC for 30% training data:  0.9999
# ROC AUC for 60% training data:  0.9999
# ROC AUC for 100% training data: 0.9999
#
# === ROC AUC Scores (Weighted Average) ===
# ROC AUC for 30% training data:  1.0000
# ROC AUC for 60% training data:  1.0000
# ROC AUC for 100% training data: 1.0000
# === LightGBM Performance Summary ===
#
# LightGBM 30%:
#   Accuracy: 0.9977
#   F1-Score: 0.9979
#   ROC AUC (Macro): 0.9999
#   ROC AUC (Weighted): 1.0000
#   Training Time: 5.340s
#   Training Samples: 70,710
#
# LightGBM 60%:
#   Accuracy: 0.9981
#   F1-Score: 0.9982
#   ROC AUC (Macro): 0.9999
#   ROC AUC (Weighted): 1.0000
#   Training Time: 3.917s
#   Training Samples: 141,420
#
# LightGBM 100%:
#   Accuracy: 0.9985
#   F1-Score: 0.9986
#   ROC AUC (Macro): 0.9999
#   ROC AUC (Weighted): 1.0000
#   Training Time: 13.199s
#   Training Samples: 235,700
#
# === Key Insights ===
# • Best Accuracy: 0.9985 with 100% training data
# • Best F1-Score: 0.9986 with 100% training data
# • Best ROC AUC (Macro): 0.9999 with 100% training data
# • Training time scales roughly linearly with data size
# • Performance improvement from 30% to 100%:
#   - Accuracy: +0.082%
#   - F1-Score: +0.066%
#   - ROC AUC: +0.002%
#
# === Efficiency Analysis ===
# 30%: 0.014109 accuracy per 1K samples, 0.076s per 1K samples
# 60%: 0.007057 accuracy per 1K samples, 0.028s per 1K samples
# 100%: 0.004236 accuracy per 1K samples, 0.056s per 1K samples
