# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, precision_recall_fscore_support
import time
import seaborn as sn

# %%
X_test = pd.read_csv('Dataset/X_test.csv')
y_test = pd.read_csv('Dataset/y_test.csv').iloc[:, 0]

X_train_30 = pd.read_csv('Dataset/X_train_30.csv')
y_train_30 = pd.read_csv('Dataset/y_train_30.csv').iloc[:, 0]

X_train_60 = pd.read_csv('Dataset/X_train_60.csv')
y_train_60 = pd.read_csv('Dataset/y_train_60.csv').iloc[:, 0]

X_train_100 = pd.read_csv('Dataset/X_train_100.csv')
y_train_100 = pd.read_csv('Dataset/y_train_100.csv').iloc[:, 0]

# %%
svm_rbf_results = {}

# %%
scaler_30 = StandardScaler()

# %%
X_train_30_scaled = scaler_30.fit_transform(X_train_30)

# %%
X_test_30_scaled = scaler_30.transform(X_test)

# %%
start_time = time.time()

# %%
svm_rbf_30 = SVC(
    kernel='rbf',
    random_state=42,
    probability=False
)

# %%
svm_rbf_30.fit(X_train_30_scaled, y_train_30)
# Out:
# SVC(random_state=42)

# %%
train_time_30 = time.time() - start_time

# %%
start_time = time.time()

# %%
y_pred_30 = svm_rbf_30.predict(X_test_30_scaled)

# %%
test_time_30 = time.time() - start_time

# %%
accuracy_30 = accuracy_score(y_test, y_pred_30)
precision, recall, f1, _ = precision_recall_fscore_support(y_test, y_pred_30, average='weighted')

# %%
svm_rbf_results['30%'] = {
    'accuracy': accuracy_30,
    'precision': precision,
    'recall': recall,
    'f1': f1,
    'train_time': train_time_30,
    'test_time': test_time_30,
    'train_samples': len(X_train_30),
    'n_support_vectors': svm_rbf_30.n_support_.sum()
}

# %%
print(f"Accuracy: {accuracy_30:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1-Score: {f1:.4f}")
print(f"Training time: {train_time_30:.4f} seconds")
print(f"Testing time: {test_time_30:.4f} seconds")
print(f"Support vectors: {svm_rbf_30.n_support_.sum()}/{len(X_train_30)} ({svm_rbf_30.n_support_.sum()/len(X_train_30)*100:.1f}%)")
print(f"Gamma: {svm_rbf_30.gamma}")
print(f"C: {svm_rbf_30.C}")
print("\nClassification Report:")
print(classification_report(y_test, y_pred_30))
# Out:
# Accuracy: 0.9731
# Precision: 0.9895
# Recall: 0.9731
# F1-Score: 0.9796
# Training time: 25.8437 seconds
# Testing time: 22.1427 seconds
# Support vectors: 5232/70710 (7.4%)
# Gamma: scale
# C: 1.0
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00     13778
#            1       0.97      0.99      0.98      3497
#            2       0.30      0.95      0.46       298
#            3       0.07      0.94      0.13        16
#            4       1.00      0.95      0.98     20203
#
#     accuracy                           0.97     37792
#    macro avg       0.67      0.97      0.71     37792
# weighted avg       0.99      0.97      0.98     37792

# %% [markdown]
# ### Train on 60%

# %%
scaler_60 = StandardScaler()

# %%
X_train_60_scaled = scaler_60.fit_transform(X_train_60)

# %%
X_test_60_scaled = scaler_60.transform(X_test)

# %%
start_time = time.time()

# %%
svm_rbf_60 = SVC(
    kernel='rbf',
    random_state=42,
    probability=False
)

# %%
svm_rbf_60.fit(X_train_60_scaled, y_train_60)
# Out:
# SVC(random_state=42)

# %%
train_time_60 = time.time() - start_time

# %%
start_time = time.time()

# %%
y_pred_60 = svm_rbf_60.predict(X_test_60_scaled)

# %%
test_time_60 = time.time() - start_time

# %%
accuracy_60 = accuracy_score(y_test, y_pred_60)
precision, recall, f1, _ = precision_recall_fscore_support(y_test, y_pred_60, average='weighted')

# %%
svm_rbf_results['60%'] = {
    'accuracy': accuracy_60,
    'precision': precision,
    'recall': recall,
    'f1': f1,
    'train_time': train_time_60,
    'test_time': test_time_60,
    'train_samples': len(X_train_60),
    'n_support_vectors': svm_rbf_60.n_support_.sum()
}

# %%
print(f"Accuracy: {accuracy_60:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1-Score: {f1:.4f}")
print(f"Training time: {train_time_60:.4f} seconds")
print(f"Testing time: {test_time_60:.4f} seconds")
print(f"Support vectors: {svm_rbf_60.n_support_.sum()}/{len(X_train_60)} ({svm_rbf_60.n_support_.sum()/len(X_train_60)*100:.1f}%)")
print(f"Gamma: {svm_rbf_60.gamma}")
print(f"C: {svm_rbf_60.C}")
print("\nClassification Report:")
print(classification_report(y_test, y_pred_60))
# Out:
# Accuracy: 0.9765
# Precision: 0.9906
# Recall: 0.9765
# F1-Score: 0.9819
# Training time: 81.3469 seconds
# Testing time: 40.3310 seconds
# Support vectors: 8385/141420 (5.9%)
# Gamma: scale
# C: 1.0
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     13778
#            1       0.98      1.00      0.99      3497
#            2       0.32      0.95      0.48       298
#            3       0.09      0.94      0.16        16
#            4       1.00      0.96      0.98     20203
#
#     accuracy                           0.98     37792
#    macro avg       0.68      0.97      0.72     37792
# weighted avg       0.99      0.98      0.98     37792

# %% [markdown]
# ### Train on 100%

# %%
scaler_100 = StandardScaler()

# %%
X_train_100_scaled = scaler_100.fit_transform(X_train_100)

# %%
X_test_100_scaled = scaler_100.transform(X_test)

# %%
start_time = time.time()

# %%
svm_rbf_100 = SVC(
    kernel='rbf',
    random_state=42,
    probability=False
)

# %%
svm_rbf_100.fit(X_train_100_scaled, y_train_100)
# Out:
# SVC(random_state=42)

# %%
train_time_100 = time.time() - start_time

# %%
y_train_pred_100 = svm_rbf_100.predict(X_train_100_scaled)
train_accuracy_100 = accuracy_score(y_train_100, y_train_pred_100)
train_precision_100, train_recall_100, train_f1_100, _ = precision_recall_fscore_support(y_train_100, y_train_pred_100, average='weighted')

# %%
start_time = time.time()

# %%
y_pred_100 = svm_rbf_100.predict(X_test_100_scaled)

# %%
test_time_100 = time.time() - start_time

# %%
accuracy_100 = accuracy_score(y_test, y_pred_100)
precision, recall, f1, _ = precision_recall_fscore_support(y_test, y_pred_100, average='weighted')

# %%
svm_rbf_results['100%'] = {
    'train_accuracy': train_accuracy_100,
    'train_precision': train_precision_100,
    'train_recall': train_recall_100,
    'train_f1': train_f1_100,
    'test_accuracy': accuracy_100,
    'test_precision': precision,
    'test_recall': recall,
    'test_f1': f1,
    'train_time': train_time_100,
    'test_time': test_time_100,
    'train_samples': len(X_train_100),
    'support_vectors': svm_rbf_100.n_support_.sum(),
    'total_samples': len(X_train_100),
    'support_vector_ratio': f"{(svm_rbf_100.n_support_.sum()/len(X_train_100)*100):.1f}%",
    'gamma': svm_rbf_100.gamma,
    'C': svm_rbf_100.C
}

# %%
print(f"Training Accuracy: {train_accuracy_100:.4f}")
print(f"Test Accuracy: {accuracy_100:.4f}")
print(f"Accuracy Gap: {(train_accuracy_100 - accuracy_100)*100:.3f}%")
print(f"Training F1-Score: {train_f1_100:.4f}")
print(f"Test F1-Score: {f1:.4f}")
print(f"F1 Gap: {(train_f1_100 - f1)*100:.3f}%")
print(f"Training time: {train_time_100:.4f} seconds")
print(f"Testing time: {test_time_100:.4f} seconds")
print(f"Support vectors: {svm_rbf_100.n_support_.sum()}/{len(X_train_100)} ({(svm_rbf_100.n_support_.sum()/len(X_train_100)*100):.1f}%)")
print(f"Gamma: {svm_rbf_100.gamma}")
print(f"C: {svm_rbf_100.C}")
print("\nTest Set Classification Report:")
print(classification_report(y_test, y_pred_100))
# Out:
# Training Accuracy: 0.9901
# Test Accuracy: 0.9789
# Accuracy Gap: 1.117%
# Training F1-Score: 0.9901
# Test F1-Score: 0.9838
# F1 Gap: 0.631%
# Training time: 116.7205 seconds
# Testing time: 51.2418 seconds
# Support vectors: 11730/235700 (5.0%)
# Gamma: scale
# C: 1.0
#
# Test Set Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     13778
#            1       0.98      1.00      0.99      3497
#            2       0.34      0.96      0.50       298
#            3       0.10      0.94      0.18        16
#            4       1.00      0.96      0.98     20203
#
#     accuracy                           0.98     37792
#    macro avg       0.68      0.97      0.73     37792
# weighted avg       0.99      0.98      0.98     37792

# %%
svm_rbf_30 = confusion_matrix(y_test, y_pred_30)
svm_rbf_60 = confusion_matrix(y_test, y_pred_60)
svm_rbf_100 = confusion_matrix(y_test, y_pred_100)
fig, axes = plt.subplots(1, 3, figsize=(15, 4))

# 30% training data
sn.heatmap(svm_rbf_30, annot=True, fmt='d', cmap='Blues', ax=axes[0])
axes[0].set_title('RBF SVM - 30% Training Data')
axes[0].set_xlabel('Predicted')
axes[0].set_ylabel('Actual')

# 60% training data
sn.heatmap(svm_rbf_60, annot=True, fmt='d', cmap='Blues', ax=axes[1])
axes[1].set_title('RBF SVM - 60% Training Data')
axes[1].set_xlabel('Predicted')
axes[1].set_ylabel('Actual')

# 100% training data
sn.heatmap(svm_rbf_100, annot=True, fmt='d', cmap='Blues', ax=axes[2])
axes[2].set_title('RBF SVM - 100% Training Data')
axes[2].set_xlabel('Predicted')
axes[2].set_ylabel('Actual')

plt.tight_layout()
plt.show()

# Print confusion matrices
print("Confusion Matrix - 30% Training Data:")
print(svm_rbf_30)
print("\nConfusion Matrix - 60% Training Data:")
print(svm_rbf_60)
print("\nConfusion Matrix - 100% Training Data:")
print(svm_rbf_100)
# Out:
# Confusion Matrix - 30% Training Data:
# [[13709    24     0     0    45]
#  [    5  3479     0     4     9]
#  [    0     0   284     5     9]
#  [    0     0     0    15     1]
#  [    6    74   649   185 19289]]
#
# Confusion Matrix - 60% Training Data:
# [[13733    21     0     0    24]
#  [    2  3483     0     4     8]
#  [    0     0   284     5     9]
#  [    0     0     0    15     1]
#  [   12    62   597   145 19387]]
#
# Confusion Matrix - 100% Training Data:
# [[13750    18     0     0    10]
#  [    2  3484     0     3     8]
#  [    0     0   285     5     8]
#  [    0     0     0    15     1]
#  [   12    51   546   132 19462]]

# %%
from sklearn.metrics import roc_auc_score, roc_curve
from sklearn.calibration import CalibratedClassifierCV
import matplotlib.pyplot as plt
import numpy as np

# First, we need to recreate the models since the variable names were overwritten by confusion matrices
# Recreate the SVM RBF models
scaler_30 = StandardScaler()
X_train_30_scaled = scaler_30.fit_transform(X_train_30)
X_test_30_scaled = scaler_30.transform(X_test)

svm_rbf_30 = SVC(kernel='rbf', random_state=42)
svm_rbf_30.fit(X_train_30_scaled, y_train_30)

scaler_60 = StandardScaler()
X_train_60_scaled = scaler_60.fit_transform(X_train_60)
X_test_60_scaled = scaler_60.transform(X_test)

svm_rbf_60 = SVC(kernel='rbf', random_state=42)
svm_rbf_60.fit(X_train_60_scaled, y_train_60)

scaler_100 = StandardScaler()
X_train_100_scaled = scaler_100.fit_transform(X_train_100)
X_test_100_scaled = scaler_100.transform(X_test)

svm_rbf_100 = SVC(kernel='rbf', random_state=42)
svm_rbf_100.fit(X_train_100_scaled, y_train_100)

# For SVM RBF, we need to use calibrated classifiers to get probabilities
# SVM doesn't naturally output probabilities that sum to 1.0
print("Calibrating SVM RBF classifiers to get probability estimates...")

# Create calibrated versions of the models
cal_svm_30 = CalibratedClassifierCV(svm_rbf_30, method='sigmoid', cv=3)
cal_svm_30.fit(X_train_30_scaled, y_train_30)

cal_svm_60 = CalibratedClassifierCV(svm_rbf_60, method='sigmoid', cv=3)
cal_svm_60.fit(X_train_60_scaled, y_train_60)

cal_svm_100 = CalibratedClassifierCV(svm_rbf_100, method='sigmoid', cv=3)
cal_svm_100.fit(X_train_100_scaled, y_train_100)

# Get probability predictions
y_pred_proba_30 = cal_svm_30.predict_proba(X_test_30_scaled)
y_pred_proba_60 = cal_svm_60.predict_proba(X_test_60_scaled)
y_pred_proba_100 = cal_svm_100.predict_proba(X_test_100_scaled)

# Check number of classes
n_classes = len(np.unique(y_test))
print(f"Number of classes: {n_classes}")
print(f"Classes: {np.unique(y_test)}")

# Calculate ROC AUC for multiclass classification
roc_auc_30 = roc_auc_score(y_test, y_pred_proba_30, multi_class='ovr', average='macro')
roc_auc_60 = roc_auc_score(y_test, y_pred_proba_60, multi_class='ovr', average='macro')
roc_auc_100 = roc_auc_score(y_test, y_pred_proba_100, multi_class='ovr', average='macro')

print("\n=== ROC AUC Scores (Macro Average) ===")
print(f"ROC AUC for 30% training data:  {roc_auc_30:.4f}")
print(f"ROC AUC for 60% training data:  {roc_auc_60:.4f}")
print(f"ROC AUC for 100% training data: {roc_auc_100:.4f}")

# Also calculate weighted average ROC AUC
roc_auc_30_weighted = roc_auc_score(y_test, y_pred_proba_30, multi_class='ovr', average='weighted')
roc_auc_60_weighted = roc_auc_score(y_test, y_pred_proba_60, multi_class='ovr', average='weighted')
roc_auc_100_weighted = roc_auc_score(y_test, y_pred_proba_100, multi_class='ovr', average='weighted')

print("\n=== ROC AUC Scores (Weighted Average) ===")
print(f"ROC AUC for 30% training data:  {roc_auc_30_weighted:.4f}")
print(f"ROC AUC for 60% training data:  {roc_auc_60_weighted:.4f}")
print(f"ROC AUC for 100% training data: {roc_auc_100_weighted:.4f}")

# Fix the results dictionary structure for consistency
# Assuming you have svm_rbf_results dictionary similar to other models
svm_rbf_results['30%']['roc_auc_macro'] = roc_auc_30
svm_rbf_results['30%']['roc_auc_weighted'] = roc_auc_30_weighted

svm_rbf_results['60%']['roc_auc_macro'] = roc_auc_60
svm_rbf_results['60%']['roc_auc_weighted'] = roc_auc_60_weighted

# Fix the 100% results structure if needed (adjust based on your actual structure)
if 'test_accuracy' in svm_rbf_results['100%']:
    svm_rbf_results['100%']['accuracy'] = svm_rbf_results['100%']['test_accuracy']
    svm_rbf_results['100%']['precision'] = svm_rbf_results['100%']['test_precision']
    svm_rbf_results['100%']['recall'] = svm_rbf_results['100%']['test_recall']
    svm_rbf_results['100%']['f1'] = svm_rbf_results['100%']['test_f1']

svm_rbf_results['100%']['roc_auc_macro'] = roc_auc_100
svm_rbf_results['100%']['roc_auc_weighted'] = roc_auc_100_weighted

# Now create the comprehensive visualization
sizes = ['30%', '60%', '100%']
accuracies = [svm_rbf_results[size]['accuracy'] for size in sizes]
f1_scores = [svm_rbf_results[size]['f1'] for size in sizes]
train_times = [svm_rbf_results[size]['train_time'] for size in sizes]
roc_macro = [svm_rbf_results[size]['roc_auc_macro'] for size in sizes]
roc_weighted = [svm_rbf_results[size]['roc_auc_weighted'] for size in sizes]

fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, figsize=(15, 10))

# 1. Performance metrics comparison
x_pos = np.arange(len(sizes))
width = 0.35

ax1.bar(x_pos - width/2, accuracies, width, label='Accuracy', alpha=0.8, color='skyblue')
ax1.bar(x_pos + width/2, f1_scores, width, label='F1-Score', alpha=0.8, color='lightcoral')
ax1.set_title('SVM RBF: Accuracy vs F1-Score', fontsize=14, fontweight='bold')
ax1.set_ylabel('Score')
ax1.set_xticks(x_pos)
ax1.set_xticklabels(sizes)
ax1.legend()
ax1.grid(True, alpha=0.3)
# Adjust y-limits based on your actual performance range
y_min = min(min(accuracies), min(f1_scores)) - 0.01
y_max = max(max(accuracies), max(f1_scores)) + 0.01
ax1.set_ylim(y_min, y_max)

# Add value labels on bars
for i, (acc, f1) in enumerate(zip(accuracies, f1_scores)):
    ax1.text(i - width/2, acc + 0.0001, f'{acc:.4f}', ha='center', fontweight='bold')
    ax1.text(i + width/2, f1 + 0.0001, f'{f1:.4f}', ha='center', fontweight='bold')

# 2. ROC AUC comparison
ax2.bar(x_pos - width/2, roc_macro, width, label='ROC AUC (Macro)', alpha=0.8, color='lightgreen')
ax2.bar(x_pos + width/2, roc_weighted, width, label='ROC AUC (Weighted)', alpha=0.8, color='gold')
ax2.set_title('SVM RBF: ROC AUC Scores', fontsize=14, fontweight='bold')
ax2.set_ylabel('ROC AUC Score')
ax2.set_xticks(x_pos)
ax2.set_xticklabels(sizes)
ax2.legend()
ax2.grid(True, alpha=0.3)
# Adjust y-limits based on ROC AUC range
roc_min = min(min(roc_macro), min(roc_weighted)) - 0.005
roc_max = max(max(roc_macro), max(roc_weighted)) + 0.005
ax2.set_ylim(roc_min, roc_max)

# Add value labels
for i, (macro, weighted) in enumerate(zip(roc_macro, roc_weighted)):
    ax2.text(i - width/2, macro + 0.0001, f'{macro:.4f}', ha='center', fontweight='bold')
    ax2.text(i + width/2, weighted + 0.0001, f'{weighted:.4f}', ha='center', fontweight='bold')

# 3. Training time
bars = ax3.bar(sizes, train_times, color='purple', alpha=0.7)
ax3.set_title('SVM RBF: Training Time', fontsize=14, fontweight='bold')
ax3.set_ylabel('Time (seconds)')
ax3.grid(True, alpha=0.3)

for i, v in enumerate(train_times):
    ax3.text(i, v + max(train_times)*0.01, f'{v:.1f}s', ha='center', fontweight='bold')

# 4. Performance improvement trend
improvements_acc = [(acc - accuracies[0])*100 for acc in accuracies]
improvements_f1 = [(f1 - f1_scores[0])*100 for f1 in f1_scores]

ax4.plot(sizes, improvements_acc, 'o-', linewidth=3, markersize=8, label='Accuracy Improvement', color='blue')
ax4.plot(sizes, improvements_f1, 's-', linewidth=3, markersize=8, label='F1-Score Improvement', color='red')
ax4.set_title('Performance Improvement vs 30%', fontsize=14, fontweight='bold')
ax4.set_ylabel('Improvement (%)')
ax4.legend()
ax4.grid(True, alpha=0.3)
ax4.axhline(y=0, color='black', linestyle='--', alpha=0.5)

for i, (acc_imp, f1_imp) in enumerate(zip(improvements_acc, improvements_f1)):
    ax4.text(i, acc_imp + 0.001, f'+{acc_imp:.3f}%', ha='center', fontweight='bold', color='blue')
    ax4.text(i, f1_imp - 0.001, f'+{f1_imp:.3f}%', ha='center', fontweight='bold', color='red')

plt.tight_layout()
plt.show()

# Print comprehensive summary
print(f"\n=== SVM RBF Performance Summary ===")
for size in sizes:
    print(f"\nSVM RBF {size}:")
    print(f"  Accuracy: {svm_rbf_results[size]['accuracy']:.4f}")
    print(f"  F1-Score: {svm_rbf_results[size]['f1']:.4f}")
    print(f"  ROC AUC (Macro): {svm_rbf_results[size]['roc_auc_macro']:.4f}")
    print(f"  ROC AUC (Weighted): {svm_rbf_results[size]['roc_auc_weighted']:.4f}")
    print(f"  Training Time: {svm_rbf_results[size]['train_time']:.3f}s")
    print(f"  Training Samples: {svm_rbf_results[size]['train_samples']:,}")

# Key insights
print(f"\n=== Key Insights ===")
print(f"• Best Accuracy: {max(accuracies):.4f} with {sizes[np.argmax(accuracies)]} training data")
print(f"• Best F1-Score: {max(f1_scores):.4f} with {sizes[np.argmax(f1_scores)]} training data")
print(f"• Best ROC AUC (Macro): {max(roc_macro):.4f} with {sizes[np.argmax(roc_macro)]} training data")
print(f"• Training time scales non-linearly with data size (RBF kernel complexity)")
print(f"• Performance improvement from 30% to 100%:")
print(f"  - Accuracy: +{(accuracies[-1] - accuracies[0])*100:.3f}%")
print(f"  - F1-Score: +{(f1_scores[-1] - f1_scores[0])*100:.3f}%")
print(f"  - ROC AUC: +{(roc_macro[-1] - roc_macro[0])*100:.3f}%")

# Performance per training sample efficiency
print(f"\n=== Efficiency Analysis ===")
for i, size in enumerate(sizes):
    samples = svm_rbf_results[size]['train_samples']
    acc_per_1k = accuracies[i] / (samples / 1000)
    time_per_1k = train_times[i] / (samples / 1000)
    print(f"{size}: {acc_per_1k:.6f} accuracy per 1K samples, {time_per_1k:.3f}s per 1K samples")

# Additional SVM RBF specific insights
print(f"\n=== SVM RBF Specific Insights ===")
print(f"• Kernel: Radial Basis Function (RBF)")
print(f"• C parameter: {svm_rbf_100.C}")
print(f"• Gamma parameter: {svm_rbf_100.gamma}")
print(f"• Number of support vectors: {svm_rbf_100.n_support_}")
print(f"• Support vector ratio: {sum(svm_rbf_100.n_support_) / len(y_train_100):.3f}")
print(f"• Requires feature scaling: Yes")
print(f"• Handles non-linear relationships: Yes")
print(f"• Memory efficient: Yes (only stores support vectors)")
# Out:
# Calibrating SVM RBF classifiers to get probability estimates...
# Number of classes: 5
# Classes: [0 1 2 3 4]
#
# === ROC AUC Scores (Macro Average) ===
# ROC AUC for 30% training data:  0.9962
# ROC AUC for 60% training data:  0.9962
# ROC AUC for 100% training data: 0.9962
#
# === ROC AUC Scores (Weighted Average) ===
# ROC AUC for 30% training data:  0.9967
# ROC AUC for 60% training data:  0.9968
# ROC AUC for 100% training data: 0.9969
# === SVM RBF Performance Summary ===
#
# SVM RBF 30%:
#   Accuracy: 0.9731
#   F1-Score: 0.9796
#   ROC AUC (Macro): 0.9962
#   ROC AUC (Weighted): 0.9967
#   Training Time: 25.844s
#   Training Samples: 70,710
#
# SVM RBF 60%:
#   Accuracy: 0.9765
#   F1-Score: 0.9819
#   ROC AUC (Macro): 0.9962
#   ROC AUC (Weighted): 0.9968
#   Training Time: 81.347s
#   Training Samples: 141,420
#
# SVM RBF 100%:
#   Accuracy: 0.9789
#   F1-Score: 0.9838
#   ROC AUC (Macro): 0.9962
#   ROC AUC (Weighted): 0.9969
#   Training Time: 116.720s
#   Training Samples: 235,700
#
# === Key Insights ===
# • Best Accuracy: 0.9789 with 100% training data
# • Best F1-Score: 0.9838 with 100% training data
# • Best ROC AUC (Macro): 0.9962 with 100% training data
# • Training time scales non-linearly with data size (RBF kernel complexity)
# • Performance improvement from 30% to 100%:
#   - Accuracy: +0.582%
#   - F1-Score: +0.418%
#   - ROC AUC: +0.001%
#
# === Efficiency Analysis ===
# 30%: 0.013762 accuracy per 1K samples, 0.365s per 1K samples
# 60%: 0.006905 accuracy per 1K samples, 0.575s per 1K samples
# 100%: 0.004153 accuracy per 1K samples, 0.495s per 1K samples
#
# === SVM RBF Specific Insights ===
# • Kernel: Radial Basis Function (RBF)
# • C parameter: 1.0
# • Gamma parameter: scale
# • Number of support vectors: [ 797  958 3878 1606 4491]
# • Support vector ratio: 0.050
# • Requires feature scaling: Yes
# • Handles non-linear relationships: Yes
# • Memory efficient: Yes (only stores support vectors)
