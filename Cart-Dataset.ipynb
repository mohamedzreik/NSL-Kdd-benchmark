# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, precision_recall_fscore_support
import time
import seaborn as sn

# %%
X_test = pd.read_csv('X_test.csv')
y_test = pd.read_csv('y_test.csv').iloc[:, 0]

X_train_30 = pd.read_csv('X_train_30.csv')
y_train_30 = pd.read_csv('y_train_30.csv').iloc[:, 0]

X_train_60 = pd.read_csv('X_train_60.csv')
y_train_60 = pd.read_csv('y_train_60.csv').iloc[:, 0]

X_train_100 = pd.read_csv('X_train_100.csv')
y_train_100 = pd.read_csv('y_train_100.csv').iloc[:, 0]

# %% [markdown]
# ### Train on 30%

# %%
start_time = time.time()

# %%
cart_30 = DecisionTreeClassifier(random_state=42)

# %%
cart_30.fit(X_train_30, y_train_30)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
train_time_30 = time.time() - start_time

# %%
start_time = time.time()

# %%
y_pred_30 = cart_30.predict(X_test)

# %%
test_time_30 = time.time() - start_time

# %%
accuracy_30 = accuracy_score(y_test, y_pred_30)
precision, recall, f1, _ = precision_recall_fscore_support(y_test, y_pred_30, average='weighted')

# %%
results= {}

# %%
results['30%'] = {
    'accuracy': accuracy_30,
    'precision': precision,
    'recall': recall,
    'f1': f1,
    'train_time': train_time_30,
    'test_time': test_time_30,
    'train_samples': len(X_train_30)
}

# %%
print(f"Accuracy: {accuracy_30:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1-Score: {f1:.4f}")
print(f"Training time: {train_time_30:.4f} seconds")
print(f"Testing time: {test_time_30:.4f} seconds")
print("\nClassification Report:")
print(classification_report(y_test, y_pred_30))
# Out:
# Accuracy: 0.9939
# Precision: 0.9950
# Recall: 0.9939
# F1-Score: 0.9943
# Training time: 0.9693 seconds
# Testing time: 0.1699 seconds
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     13778
#            1       0.99      0.99      0.99      3497
#            2       0.82      0.94      0.88       298
#            3       0.11      0.38      0.17        16
#            4       1.00      0.99      0.99     20203
#
#     accuracy                           0.99     37792
#    macro avg       0.78      0.86      0.81     37792
# weighted avg       0.99      0.99      0.99     37792

# %% [markdown]
# ### Train on 60%

# %%
start_time = time.time()

# %%
cart_60 = DecisionTreeClassifier(random_state=42)

# %%
cart_60.fit(X_train_60, y_train_60)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
train_time_60 = time.time() - start_time

# %%
start_time = time.time()

# %%
y_pred_60 = cart_60.predict(X_test)

# %%
test_time_60 = time.time() - start_time

# %%
accuracy_60 = accuracy_score(y_test, y_pred_60)
precision, recall, f1, _ = precision_recall_fscore_support(y_test, y_pred_60, average='weighted')

# %%
results['60%'] = {
    'accuracy': accuracy_60,
    'precision': precision,
    'recall': recall,
    'f1': f1,
    'train_time': train_time_60,
    'test_time': test_time_60,
    'train_samples': len(X_train_60)
}

# %%
print(f"Accuracy: {accuracy_60:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1-Score: {f1:.4f}")
print(f"Training time: {train_time_60:.4f} seconds")
print(f"Testing time: {test_time_60:.4f} seconds")
print("\nClassification Report:")
print(classification_report(y_test, y_pred_60))
# Out:
# Accuracy: 0.9956
# Precision: 0.9962
# Recall: 0.9956
# F1-Score: 0.9958
# Training time: 3.7846 seconds
# Testing time: 0.1443 seconds
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     13778
#            1       0.99      1.00      0.99      3497
#            2       0.86      0.96      0.91       298
#            3       0.19      0.44      0.27        16
#            4       1.00      0.99      1.00     20203
#
#     accuracy                           1.00     37792
#    macro avg       0.81      0.88      0.83     37792
# weighted avg       1.00      1.00      1.00     37792

# %% [markdown]
# ### Train on 100%

# %%
start_time = time.time()

# %%
cart_100 = DecisionTreeClassifier(random_state=42)

# %%
cart_100.fit(X_train_100, y_train_100)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
train_time_100 = time.time() - start_time

# %%
y_train_pred_100 = cart_100.predict(X_train_100)
train_accuracy_100 = accuracy_score(y_train_100, y_train_pred_100)
train_precision_100, train_recall_100, train_f1_100, _ = precision_recall_fscore_support(y_train_100, y_train_pred_100, average='weighted')

# %%
start_time = time.time()

# %%
y_pred_100 = cart_100.predict(X_test)

# %%
test_time_100 = time.time() - start_time

# %%
accuracy_100 = accuracy_score(y_test, y_pred_100)
precision, recall, f1, _ = precision_recall_fscore_support(y_test, y_pred_100, average='weighted')

# %%
results['100%'] = {
    'accuracy': accuracy_100,
    'precision': precision,
    'recall': recall,
    'f1': f1,
    'train_accuracy': train_accuracy_100,
    'train_precision': train_precision_100,
    'train_recall': train_recall_100,
    'train_f1': train_f1_100,
    'train_time': train_time_100,
    'test_time': test_time_100,
    'train_samples': len(X_train_100)
}

# %%
# Print results
print("=== Training Performance ===")
print(f"Training Accuracy: {train_accuracy_100:.4f}")
print(f"Training Precision: {train_precision_100:.4f}")
print(f"Training Recall: {train_recall_100:.4f}")
print(f"Training F1-Score: {train_f1_100:.4f}")

print("\n=== Test Performance ===")
print(f"Accuracy: {accuracy_100:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1-Score: {f1:.4f}")

print(f"\nTraining time: {train_time_100:.4f} seconds")
print(f"Testing time: {test_time_100:.4f} seconds")

print("\nClassification Report:")
print(classification_report(y_test, y_pred_100))
# Out:
# === Training Performance ===
# Training Accuracy: 1.0000
# Training Precision: 1.0000
# Training Recall: 1.0000
# Training F1-Score: 1.0000
#
# === Test Performance ===
# Accuracy: 0.9963
# Precision: 0.9969
# Recall: 0.9963
# F1-Score: 0.9966
#
# Training time: 5.0325 seconds
# Testing time: 0.1108 seconds
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     13778
#            1       0.99      0.99      0.99      3497
#            2       0.93      0.96      0.94       298
#            3       0.20      0.56      0.30        16
#            4       1.00      1.00      1.00     20203
#
#     accuracy                           1.00     37792
#    macro avg       0.82      0.90      0.85     37792
# weighted avg       1.00      1.00      1.00     37792

# %%
cart_30 = confusion_matrix(y_test, y_pred_30)
cart_60 = confusion_matrix(y_test, y_pred_60)
cart_100 = confusion_matrix(y_test, y_pred_100)
fig, axes = plt.subplots(1, 3, figsize=(15, 4))

# 30% training data
sn.heatmap(cart_30, annot=True, fmt='d', cmap='Blues', ax=axes[0])
axes[0].set_title('cart - 30% Training Data')
axes[0].set_xlabel('Predicted')
axes[0].set_ylabel('Actual')

# 60% training data
sn.heatmap(cart_60, annot=True, fmt='d', cmap='Blues', ax=axes[1])
axes[1].set_title('cart - 60% Training Data')
axes[1].set_xlabel('Predicted')
axes[1].set_ylabel('Actual')

# 100% training data
sn.heatmap(cm_100, annot=True, fmt='d', cmap='Blues', ax=axes[2])
axes[2].set_title('cart - 100% Training Data')
axes[2].set_xlabel('Predicted')
axes[2].set_ylabel('Actual')

plt.tight_layout()
plt.show()

# Print confusion matrices
print("Confusion Matrix - 30% Training Data:")
print(cart_30)
print("\nConfusion Matrix - 60% Training Data:")
print(cart_60)
print("\nConfusion Matrix - 100% Training Data:")
print(cart_100)
# Out:
# Confusion Matrix - 30% Training Data:
# [[13763     1     0     1    13]
#  [    3  3473     1     0    20]
#  [    0     0   281     1    16]
#  [    0     2     3     6     5]
#  [   17    45    59    45 20037]]
#
# Confusion Matrix - 60% Training Data:
# [[13766     3     0     1     8]
#  [    2  3481     0     0    14]
#  [    0     0   286     0    12]
#  [    0     2     1     7     6]
#  [   13    32    44    28 20086]]
#
# Confusion Matrix - 100% Training Data:
# [[13771     0     0     1     6]
#  [    3  3477     0     0    17]
#  [    0     1   285     1    11]
#  [    0     0     1     9     6]
#  [    8    30    22    33 20110]]

# %%
from sklearn.metrics import roc_auc_score, roc_curve
import matplotlib.pyplot as plt
import numpy as np

# Fix variable naming - use the actual model objects, not confusion matrices
model_30 = DecisionTreeClassifier(random_state=42)
model_30.fit(X_train_30, y_train_30)

model_60 = DecisionTreeClassifier(random_state=42)
model_60.fit(X_train_60, y_train_60)

model_100 = DecisionTreeClassifier(random_state=42)
model_100.fit(X_train_100, y_train_100)

# Get prediction probabilities
y_pred_proba_30 = model_30.predict_proba(X_test)
y_pred_proba_60 = model_60.predict_proba(X_test)
y_pred_proba_100 = model_100.predict_proba(X_test)

# Check number of classes
n_classes = len(np.unique(y_test))
print(f"Number of classes: {n_classes}")
print(f"Classes: {np.unique(y_test)}")

# Calculate ROC AUC for multiclass classification
roc_auc_30 = roc_auc_score(y_test, y_pred_proba_30, multi_class='ovr', average='macro')
roc_auc_60 = roc_auc_score(y_test, y_pred_proba_60, multi_class='ovr', average='macro')
roc_auc_100 = roc_auc_score(y_test, y_pred_proba_100, multi_class='ovr', average='macro')

print("\n=== ROC AUC Scores ===")
print(f"ROC AUC for 30% training data:  {roc_auc_30:.4f}")
print(f"ROC AUC for 60% training data:  {roc_auc_60:.4f}")
print(f"ROC AUC for 100% training data: {roc_auc_100:.4f}")

# Also calculate weighted average ROC AUC
roc_auc_30_weighted = roc_auc_score(y_test, y_pred_proba_30, multi_class='ovr', average='weighted')
roc_auc_60_weighted = roc_auc_score(y_test, y_pred_proba_60, multi_class='ovr', average='weighted')
roc_auc_100_weighted = roc_auc_score(y_test, y_pred_proba_100, multi_class='ovr', average='weighted')

print("\n=== ROC AUC Scores (Weighted) ===")
print(f"ROC AUC for 30% training data:  {roc_auc_30_weighted:.4f}")
print(f"ROC AUC for 60% training data:  {roc_auc_60_weighted:.4f}")
print(f"ROC AUC for 100% training data: {roc_auc_100_weighted:.4f}")

# Update results dictionary with ROC AUC scores
results['30%']['roc_auc_macro'] = roc_auc_30
results['30%']['roc_auc_weighted'] = roc_auc_30_weighted

results['60%']['roc_auc_macro'] = roc_auc_60
results['60%']['roc_auc_weighted'] = roc_auc_60_weighted

results['100%']['roc_auc_macro'] = roc_auc_100
results['100%']['roc_auc_weighted'] = roc_auc_100_weighted

# Create a summary comparison
print("\n=== Performance Comparison Summary ===")
training_sizes = ['30%', '60%', '100%']
metrics = ['accuracy', 'precision', 'recall', 'f1', 'roc_auc_macro', 'roc_auc_weighted', 'train_time', 'test_time']

for metric in metrics:
    print(f"\n{metric.upper()}:")
    for size in training_sizes:
        if metric in results[size]:
            if 'time' in metric:
                print(f"  {size}: {results[size][metric]:.4f} seconds")
            else:
                print(f"  {size}: {results[size][metric]:.4f}")

# Visualize ROC AUC comparison
plt.figure(figsize=(10, 6))
training_percentages = [30, 60, 100]
macro_scores = [roc_auc_30, roc_auc_60, roc_auc_100]
weighted_scores = [roc_auc_30_weighted, roc_auc_60_weighted, roc_auc_100_weighted]

plt.plot(training_percentages, macro_scores, 'b-o', label='ROC AUC (Macro)', linewidth=2, markersize=8)
plt.plot(training_percentages, weighted_scores, 'r-s', label='ROC AUC (Weighted)', linewidth=2, markersize=8)

plt.xlabel('Training Data Percentage (%)')
plt.ylabel('ROC AUC Score')
plt.title('ROC AUC Performance vs Training Data Size')
plt.legend()
plt.grid(True, alpha=0.3)
plt.xticks(training_percentages)
plt.ylim(0.8, 1.0)

for i, (macro, weighted) in enumerate(zip(macro_scores, weighted_scores)):
    plt.annotate(f'{macro:.3f}', (training_percentages[i], macro),
                textcoords="offset points", xytext=(0,10), ha='center')
    plt.annotate(f'{weighted:.3f}', (training_percentages[i], weighted),
                textcoords="offset points", xytext=(0,-15), ha='center')

plt.tight_layout()
plt.show()

print(f"\n=== Key Insights ===")
print(f"• Best ROC AUC (Macro): {max(macro_scores):.4f} with {training_percentages[np.argmax(macro_scores)]}% training data")
print(f"• Best ROC AUC (Weighted): {max(weighted_scores):.4f} with {training_percentages[np.argmax(weighted_scores)]}% training data")
print(f"• ROC AUC improvement from 30% to 100%: {((roc_auc_100 - roc_auc_30) / roc_auc_30 * 100):.2f}%")
# Out:
# Number of classes: 5
# Classes: [0 1 2 3 4]
#
# === ROC AUC Scores ===
# ROC AUC for 30% training data:  0.9294
# ROC AUC for 60% training data:  0.9380
# ROC AUC for 100% training data: 0.9503
#
# === ROC AUC Scores (Weighted) ===
# ROC AUC for 30% training data:  0.9959
# ROC AUC for 60% training data:  0.9971
# ROC AUC for 100% training data: 0.9974
#
# === Performance Comparison Summary ===
#
# ACCURACY:
#   30%: 0.9939
#   60%: 0.9956
#   100%: 0.9963
#
# PRECISION:
#   30%: 0.9950
#   60%: 0.9962
#   100%: 0.9969
#
# RECALL:
#   30%: 0.9939
#   60%: 0.9956
#   100%: 0.9963
#
# F1:
#   30%: 0.9943
#   60%: 0.9958
#   100%: 0.9966
#
# ROC_AUC_MACRO:
#   30%: 0.9294
#   60%: 0.9380
#   100%: 0.9503
#
# ROC_AUC_WEIGHTED:
#   30%: 0.9959
#   60%: 0.9971
#   100%: 0.9974
#
# TRAIN_TIME:
#   30%: 0.9693 seconds
#   60%: 3.7846 seconds
#   100%: 5.0325 seconds
#
# TEST_TIME:
#   30%: 0.1699 seconds
#   60%: 0.1443 seconds
#   100%: 0.1108 seconds
# === Key Insights ===
# ...

# %%
print(type(cart_30)) # Or cart_60, cart_100
# Out:
# <class 'numpy.ndarray'>
